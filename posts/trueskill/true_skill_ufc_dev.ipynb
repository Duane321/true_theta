# %%
import pandas as pd
import numpy as np
import altair as alt
import requests
from bs4 import BeautifulSoup
import json
import urllib.parse
from collections import Counter

# %%
from true_skill_through_time import *

# %%
# ufc_wiki_urls contains the wikipedia URLs of a large list of ufc fighters
with open('data/ufc_wiki_urls.txt', 'r') as file:
    urls = file.readlines()

urls = [url.strip() for url in urls]

# %%
with open('data/ufc_wiki_urls_v2.txt', 'r') as file:
    urls_v2 = file.readlines()
urls_v2 = [url.strip() for url in urls_v2]

# %%
len(urls), len(urls_v2)
# Out:
# (385, 389)

# %%
added_url_lst = [url for url in urls_v2 if url not in urls]

# %%
def extract_ufc_record(url):
    """
    Given a ufc's Wikipedia URL, this will extract the table called "Mixed martial arts record" and do some cleanup.
    """
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    section = None
    for header in soup.find_all(['h2', 'h3', 'h4']):
        if 'Mixed martial arts record' in header.get_text():
            section = header
            break
    
    if section:
        tables = section.find_all_next('table')
        
        for table in tables:
            first_row = table.find('tr')
            columns = first_row.find_all(['th', 'td'])
            
            if len(columns) >= 4:
                headers = [header.get_text(strip=True) for header in table.find_all('th')]
                rows = []
                for row in table.find_all('tr')[1:]:  # Skip header row if present
                    cells = row.find_all(['th', 'td'])
                    rows.append([cell.get_text(strip=True) for cell in cells])
                df = pd.DataFrame(rows, columns=headers if headers else None).rename(columns={'Date': "Date raw", 'Res.':'Result'})
                return df 
                
    print('No suitable table found with at least 4 columns.')
    return None

# %%
ufc_records = {}

for url in urls[:]:
    print(url)
    fighter_name = url[30:]
    print('fighter_name:', fighter_name)
    try:
        record = extract_ufc_record(url)
        if record is not None:
            ufc_records[fighter_name] = record
    except:
        print(f"broke on: {url}")
# Out:
# https://en.wikipedia.org/wiki/Derrick_Lewis
# fighter_name: Derrick_Lewis
# https://en.wikipedia.org/wiki/Jack_Della_Maddalena
# fighter_name: Jack_Della_Maddalena
# https://en.wikipedia.org/wiki/Kelvin_Gastelum
# fighter_name: Kelvin_Gastelum
# https://en.wikipedia.org/wiki/Reinier_de_Ridder
# fighter_name: Reinier_de_Ridder
# https://en.wikipedia.org/wiki/Vitor_Petrino
# fighter_name: Vitor_Petrino
# https://en.wikipedia.org/wiki/Carlos_Ulberg
# fighter_name: Carlos_Ulberg
# https://en.wikipedia.org/wiki/Drakkar_Klose
# fighter_name: Drakkar_Klose
# https://en.wikipedia.org/wiki/Kang_Kyung-ho
# fighter_name: Kang_Kyung-ho
# https://en.wikipedia.org/wiki/Daniel_Pineda_(fighter)
# fighter_name: Daniel_Pineda_(fighter)
# https://en.wikipedia.org/wiki/Walt_Harris_(fighter)
# fighter_name: Walt_Harris_(fighter)
# https://en.wikipedia.org/wiki/Andre_Petroski
# fighter_name: Andre_Petroski
# https://en.wikipedia.org/wiki/Rinya_Nakamura
# fighter_name: Rinya_Nakamura
# https://en.wikipedia.org/wiki/Jonathan_Martinez
# fighter_name: Jonathan_Martinez
# https://en.wikipedia.org/wiki/Ian_Machado_Garry
# fighter_name: Ian_Machado_Garry
# https://en.wikipedia.org/wiki/Valentina_Shevchenko
# fighter_name: Valentina_Shevchenko
# https://en.wikipedia.org/wiki/Andrea_Lee_(fighter)
# fighter_name: Andrea_Lee_(fighter)
# https://en.wikipedia.org/wiki/Joselyne_Edwards
# fighter_name: Joselyne_Edwards
# https://en.wikipedia.org/wiki/Ismail_Naurdiev
# fighter_name: Ismail_Naurdiev
# https://en.wikipedia.org/wiki/Court_McGee
# fighter_name: Court_McGee
# https://en.wikipedia.org/wiki/Kayla_Harrison
# fighter_name: Kayla_Harrison
# https://en.wikipedia.org/wiki/Tracy_Cortez
# fighter_name: Tracy_Cortez
# https://en.wikipedia.org/wiki/Santiago_Ponzinibbio
# fighter_name: Santiago_Ponzinibbio
# https://en.wikipedia.org/wiki/Cheyanne_Vlismas
# fighter_name: Cheyanne_Vlismas
# https://en.wikipedia.org/wiki/Jessica_Andrade
# fighter_name: Jessica_Andrade
# https://en.wikipedia.org/wiki/Billy_Quarantillo
# fighter_name: Billy_Quarantillo
# https://en.wikipedia.org/wiki/Li_Jingliang
# fighter_name: Li_Jingliang
# https://en.wikipedia.org/wiki/Zhang_Weili
# fighter_name: Zhang_Weili
# https://en.wikipedia.org/wiki/Nicolae_Negumereanu
# fighter_name: Nicolae_Negumereanu
# https://en.wikipedia.org/wiki/Denise_Gomes
# fighter_name: Denise_Gomes
# https://en.wikipedia.org/wiki/Trevin_Giles
# fighter_name: Trevin_Giles
# https://en.wikipedia.org/wiki/Nursulton_Ruziboev
# fighter_name: Nursulton_Ruziboev
# https://en.wikipedia.org/wiki/Elizeu_Zaleski_dos_Santos
# fighter_name: Elizeu_Zaleski_dos_Santos
# https://en.wikipedia.org/wiki/Arman_Tsarukyan
# fighter_name: Arman_Tsarukyan
# https://en.wikipedia.org/wiki/Said_Nurmagomedov
# fighter_name: Said_Nurmagomedov
# https://en.wikipedia.org/wiki/Miles_Johns
# fighter_name: Miles_Johns
# https://en.wikipedia.org/wiki/Mackenzie_Dern
# fighter_name: Mackenzie_Dern
# https://en.wikipedia.org/wiki/Viviane_Ara%C3%BAjo_(fighter)
# fighter_name: Viviane_Ara%C3%BAjo_(fighter)
# https://en.wikipedia.org/wiki/Carlston_Harris
# fighter_name: Carlston_Harris
# https://en.wikipedia.org/wiki/Brogan_Walker
# fighter_name: Brogan_Walker
# https://en.wikipedia.org/wiki/Armenia
# fighter_name: Armenia
# No suitable table found with at least 4 columns.
# https://en.wikipedia.org/wiki/Alex_Perez_(fighter)
# fighter_name: Alex_Perez_(fighter)
# https://en.wikipedia.org/wiki/Irene_Aldana
# fighter_name: Irene_Aldana
# https://en.wikipedia.org/wiki/Mike_Malott
# fighter_name: Mike_Malott
# https://en.wikipedia.org/wiki/Justin_Tafa
# fighter_name: Justin_Tafa
# https://en.wikipedia.org/wiki/Angela_Hill
# fighter_name: Angela_Hill
# https://en.wikipedia.org/wiki/Erin_Blanchfield
# fighter_name: Erin_Blanchfield
# https://en.wikipedia.org/wiki/Javid_Basharat
# fighter_name: Javid_Basharat
# https://en.wikipedia.org/wiki/Jordan_Leavitt
# fighter_name: Jordan_Leavitt
# https://en.wikipedia.org/wiki/Gabriel_Green_(fighter)
# fighter_name: Gabriel_Green_(fighter)
# https://en.wikipedia.org/wiki/Ariane_da_Silva
# fighter_name: Ariane_da_Silva
# https://en.wikipedia.org/wiki/Kron_Gracie
# fighter_name: Kron_Gracie
# https://en.wikipedia.org/wiki/Brad_Katona
# fighter_name: Brad_Katona
# https://en.wikipedia.org/wiki/Matheus_Nicolau
# fighter_name: Matheus_Nicolau
# https://en.wikipedia.org/wiki/Ricky_Sim%C3%B3n
# fighter_name: Ricky_Sim%C3%B3n
# https://en.wikipedia.org/wiki/Dominick_Reyes
# fighter_name: Dominick_Reyes
# https://en.wikipedia.org/wiki/Drew_Dober
# fighter_name: Drew_Dober
# https://en.wikipedia.org/wiki/Jonathan_Pearce_(fighter)
# fighter_name: Jonathan_Pearce_(fighter)
# https://en.wikipedia.org/wiki/Luana_Pinheiro
# fighter_name: Luana_Pinheiro
# https://en.wikipedia.org/wiki/Jos%C3%A9_Aldo
# fighter_name: Jos%C3%A9_Aldo
# https://en.wikipedia.org/wiki/Chris_Guti%C3%A9rrez
# fighter_name: Chris_Guti%C3%A9rrez
# https://en.wikipedia.org/wiki/Wang_Cong
# fighter_name: Wang_Cong
# https://en.wikipedia.org/wiki/Brendan_Allen
# fighter_name: Brendan_Allen
# https://en.wikipedia.org/wiki/Aljamain_Sterling
# fighter_name: Aljamain_Sterling
# https://en.wikipedia.org/wiki/Khalil_Rountree_Jr.
# fighter_name: Khalil_Rountree_Jr.
# https://en.wikipedia.org/wiki/Justin_Gaethje
# fighter_name: Justin_Gaethje
# https://en.wikipedia.org/wiki/Anthony_Hernandez
# fighter_name: Anthony_Hernandez
# https://en.wikipedia.org/wiki/Cody_Durden
# fighter_name: Cody_Durden
# https://en.wikipedia.org/wiki/Paul_Craig
# fighter_name: Paul_Craig
# https://en.wikipedia.org/wiki/Anthony_Smith_(fighter)
# fighter_name: Anthony_Smith_(fighter)
# https://en.wikipedia.org/wiki/Joe_Pyfer
# fighter_name: Joe_Pyfer
# https://en.wikipedia.org/wiki/Hamdy_Abdelwahab
# fighter_name: Hamdy_Abdelwahab
# https://en.wikipedia.org/wiki/Cub_Swanson
# fighter_name: Cub_Swanson
# https://en.wikipedia.org/wiki/Jailton_Almeida
# fighter_name: Jailton_Almeida
# https://en.wikipedia.org/wiki/Cory_McKenna
# fighter_name: Cory_McKenna
# https://en.wikipedia.org/wiki/Bogdan_Guskov
# fighter_name: Bogdan_Guskov
# https://en.wikipedia.org/wiki/Brandon_Moreno
# fighter_name: Brandon_Moreno
# https://en.wikipedia.org/wiki/Aiemann_Zahabi
# fighter_name: Aiemann_Zahabi
# https://en.wikipedia.org/wiki/Muhammad_Naimov
# fighter_name: Muhammad_Naimov
# https://en.wikipedia.org/wiki/Lerone_Murphy
# fighter_name: Lerone_Murphy
# https://en.wikipedia.org/wiki/Claudio_Puelles
# fighter_name: Claudio_Puelles
# https://en.wikipedia.org/wiki/Raquel_Pennington
# fighter_name: Raquel_Pennington
# https://en.wikipedia.org/wiki/Dominick_Cruz
# fighter_name: Dominick_Cruz
# https://en.wikipedia.org/wiki/Julian_Erosa
# fighter_name: Julian_Erosa
# https://en.wikipedia.org/wiki/Molly_McCann
# fighter_name: Molly_McCann
# https://en.wikipedia.org/wiki/Jared_Gooden
# fighter_name: Jared_Gooden
# https://en.wikipedia.org/wiki/C%C3%A9sar_Almeida_(fighter)
# fighter_name: C%C3%A9sar_Almeida_(fighter)
# https://en.wikipedia.org/wiki/Dustin_Jacoby
# fighter_name: Dustin_Jacoby
# https://en.wikipedia.org/wiki/Joe_Solecki
# fighter_name: Joe_Solecki
# https://en.wikipedia.org/wiki/Matt_Schnell
# fighter_name: Matt_Schnell
# https://en.wikipedia.org/wiki/Cody_Brundage
# fighter_name: Cody_Brundage
# https://en.wikipedia.org/wiki/Jake_Matthews_(fighter)
# fighter_name: Jake_Matthews_(fighter)
# https://en.wikipedia.org/wiki/Shayilan_Nuerdanbieke
# fighter_name: Shayilan_Nuerdanbieke
# https://en.wikipedia.org/wiki/Rafa_Garc%C3%ADa_(fighter)
# fighter_name: Rafa_Garc%C3%ADa_(fighter)
# https://en.wikipedia.org/wiki/Lucie_Pudilov%C3%A1
# fighter_name: Lucie_Pudilov%C3%A1
# https://en.wikipedia.org/wiki/Joshua_Culibao
# fighter_name: Joshua_Culibao
# https://en.wikipedia.org/wiki/Michael_Morales_(fighter)
# fighter_name: Michael_Morales_(fighter)
# https://en.wikipedia.org/wiki/Diana_Belbi%C5%A3%C4%83
# fighter_name: Diana_Belbi%C5%A3%C4%83
# https://en.wikipedia.org/wiki/Austin_Hubbard
# fighter_name: Austin_Hubbard
# https://en.wikipedia.org/wiki/Rani_Yahya
# fighter_name: Rani_Yahya
# https://en.wikipedia.org/wiki/Jimmy_Crute
# fighter_name: Jimmy_Crute
# https://en.wikipedia.org/wiki/Chelsea_Chandler
# fighter_name: Chelsea_Chandler
# https://en.wikipedia.org/wiki/Youssef_Zalal
# fighter_name: Youssef_Zalal
# https://en.wikipedia.org/wiki/Rodrigo_Nascimento
# fighter_name: Rodrigo_Nascimento
# https://en.wikipedia.org/wiki/Carla_Esparza
# fighter_name: Carla_Esparza
# https://en.wikipedia.org/wiki/Matthew_Semelsberger
# fighter_name: Matthew_Semelsberger
# https://en.wikipedia.org/wiki/Sam_Hughes_(fighter)
# fighter_name: Sam_Hughes_(fighter)
# https://en.wikipedia.org/wiki/Leon_Edwards
# fighter_name: Leon_Edwards
# https://en.wikipedia.org/wiki/Maycee_Barber
# fighter_name: Maycee_Barber
# https://en.wikipedia.org/wiki/Daniel_Zellhuber
# fighter_name: Daniel_Zellhuber
# https://en.wikipedia.org/wiki/Roosevelt_Roberts
# fighter_name: Roosevelt_Roberts
# https://en.wikipedia.org/wiki/Umar_Nurmagomedov
# fighter_name: Umar_Nurmagomedov
# https://en.wikipedia.org/wiki/Tatiana_Suarez
# fighter_name: Tatiana_Suarez
# https://en.wikipedia.org/wiki/John_Casta%C3%B1eda
# fighter_name: John_Casta%C3%B1eda
# https://en.wikipedia.org/wiki/Jim_Miller_(fighter)
# fighter_name: Jim_Miller_(fighter)
# https://en.wikipedia.org/wiki/Dan_Hooker
# fighter_name: Dan_Hooker
# https://en.wikipedia.org/wiki/Islam_Makhachev
# fighter_name: Islam_Makhachev
# https://en.wikipedia.org/wiki/Anshul_Jubli
# fighter_name: Anshul_Jubli
# https://en.wikipedia.org/wiki/Amanda_Ribas
# fighter_name: Amanda_Ribas
# https://en.wikipedia.org/wiki/Julia_Avila
# fighter_name: Julia_Avila
# https://en.wikipedia.org/wiki/Calvin_Kattar
# fighter_name: Calvin_Kattar
# https://en.wikipedia.org/wiki/Gunnar_Nelson_(fighter)
# fighter_name: Gunnar_Nelson_(fighter)
# https://en.wikipedia.org/wiki/Paddy_Pimblett
# fighter_name: Paddy_Pimblett
# https://en.wikipedia.org/wiki/Charles_Jourdain
# fighter_name: Charles_Jourdain
# https://en.wikipedia.org/wiki/Khamzat_Chimaev
# fighter_name: Khamzat_Chimaev
# https://en.wikipedia.org/wiki/Alexander_Hernandez
# fighter_name: Alexander_Hernandez
# https://en.wikipedia.org/wiki/J%C3%A9ssica_Andrade
# fighter_name: J%C3%A9ssica_Andrade
# https://en.wikipedia.org/wiki/Julija_Stoliarenko
# fighter_name: Julija_Stoliarenko
# https://en.wikipedia.org/wiki/Alex_Pereira
# fighter_name: Alex_Pereira
# https://en.wikipedia.org/wiki/Ketlen_Souza
# fighter_name: Ketlen_Souza
# https://en.wikipedia.org/wiki/Henry_Cejudo
# fighter_name: Henry_Cejudo
# https://en.wikipedia.org/wiki/Joaquin_Buckley
# fighter_name: Joaquin_Buckley
# https://en.wikipedia.org/wiki/Sean_Brady_(fighter)
# fighter_name: Sean_Brady_(fighter)
# https://en.wikipedia.org/wiki/Hakeem_Dawodu
# fighter_name: Hakeem_Dawodu
# https://en.wikipedia.org/wiki/Petr_Yan
# fighter_name: Petr_Yan
# https://en.wikipedia.org/wiki/Arnold_Allen
# fighter_name: Arnold_Allen
# https://en.wikipedia.org/wiki/Marvin_Vettori
# fighter_name: Marvin_Vettori
# https://en.wikipedia.org/wiki/Rafael_dos_Anjos
# fighter_name: Rafael_dos_Anjos
# https://en.wikipedia.org/wiki/Max_Griffin
# fighter_name: Max_Griffin
# https://en.wikipedia.org/wiki/C.J._Vergara
# fighter_name: C.J._Vergara
# https://en.wikipedia.org/wiki/Karol_Rosa
# fighter_name: Karol_Rosa
# https://en.wikipedia.org/wiki/Karolina_Kowalkiewicz
# fighter_name: Karolina_Kowalkiewicz
# https://en.wikipedia.org/wiki/Brian_Kelleher
# fighter_name: Brian_Kelleher
# https://en.wikipedia.org/wiki/Miranda_Maverick
# fighter_name: Miranda_Maverick
# https://en.wikipedia.org/wiki/Roman_Kopylov
# fighter_name: Roman_Kopylov
# https://en.wikipedia.org/wiki/Cody_Garbrandt
# fighter_name: Cody_Garbrandt
# https://en.wikipedia.org/wiki/Jon_Jones
# fighter_name: Jon_Jones
# https://en.wikipedia.org/wiki/Anthony_Hernandez_(fighter)
# fighter_name: Anthony_Hernandez_(fighter)
# https://en.wikipedia.org/wiki/Montana_De_La_Rosa
# fighter_name: Montana_De_La_Rosa
# https://en.wikipedia.org/wiki/Damir_Had%C5%BEovi%C4%87
# fighter_name: Damir_Had%C5%BEovi%C4%87
# https://en.wikipedia.org/wiki/Loopy_Godinez
# fighter_name: Loopy_Godinez
# https://en.wikipedia.org/wiki/Ryan_Spann
# fighter_name: Ryan_Spann
# https://en.wikipedia.org/wiki/Damon_Jackson
# fighter_name: Damon_Jackson
# https://en.wikipedia.org/wiki/Diego_Lopes_(fighter)
# fighter_name: Diego_Lopes_(fighter)
# https://en.wikipedia.org/wiki/Movsar_Evloev
# fighter_name: Movsar_Evloev
# https://en.wikipedia.org/wiki/Far%C3%A8s_Ziam
# fighter_name: Far%C3%A8s_Ziam
# https://en.wikipedia.org/wiki/Cory_Sandhagen
# fighter_name: Cory_Sandhagen
# https://en.wikipedia.org/wiki/Aori_Qileng
# fighter_name: Aori_Qileng
# https://en.wikipedia.org/wiki/Islam_Dulatov
# fighter_name: Islam_Dulatov
# https://en.wikipedia.org/wiki/Deiveson_Figueiredo
# fighter_name: Deiveson_Figueiredo
# https://en.wikipedia.org/wiki/Gregory_Rodrigues
# fighter_name: Gregory_Rodrigues
# https://en.wikipedia.org/wiki/Maryna_Moroz
# fighter_name: Maryna_Moroz
# https://en.wikipedia.org/wiki/Nicolas_Dalby
# fighter_name: Nicolas_Dalby
# https://en.wikipedia.org/wiki/Alateng_Heili
# fighter_name: Alateng_Heili
# https://en.wikipedia.org/wiki/Sergei_Pavlovich
# fighter_name: Sergei_Pavlovich
# https://en.wikipedia.org/wiki/Nat%C3%A1lia_Silva_(fighter)
# fighter_name: Nat%C3%A1lia_Silva_(fighter)
# https://en.wikipedia.org/wiki/Jack_Hermansson
# fighter_name: Jack_Hermansson
# https://en.wikipedia.org/wiki/George_Piro
# fighter_name: George_Piro
# No suitable table found with at least 4 columns.
# https://en.wikipedia.org/wiki/Alexa_Grasso
# fighter_name: Alexa_Grasso
# https://en.wikipedia.org/wiki/Jeka_Saragih
# fighter_name: Jeka_Saragih
# https://en.wikipedia.org/wiki/Andrei_Arlovski
# fighter_name: Andrei_Arlovski
# https://en.wikipedia.org/wiki/Andr%C3%A9_Muniz
# fighter_name: Andr%C3%A9_Muniz
# https://en.wikipedia.org/wiki/Charles_Oliveira
# fighter_name: Charles_Oliveira
# https://en.wikipedia.org/wiki/Jean_Silva
# fighter_name: Jean_Silva
# https://en.wikipedia.org/wiki/Sean_Strickland
# fighter_name: Sean_Strickland
# https://en.wikipedia.org/wiki/Casey_O%27Neill
# fighter_name: Casey_O%27Neill
# https://en.wikipedia.org/wiki/Tony_Ferguson
# fighter_name: Tony_Ferguson
# https://en.wikipedia.org/wiki/Alex_Caceres
# fighter_name: Alex_Caceres
# https://en.wikipedia.org/wiki/Rob_Font
# fighter_name: Rob_Font
# https://en.wikipedia.org/wiki/Jared_Cannonier
# fighter_name: Jared_Cannonier
# https://en.wikipedia.org/wiki/Jacob_Malkoun
# fighter_name: Jacob_Malkoun
# https://en.wikipedia.org/wiki/Lauren_Murphy
# fighter_name: Lauren_Murphy
# https://en.wikipedia.org/wiki/Michel_Pereira
# fighter_name: Michel_Pereira
# https://en.wikipedia.org/wiki/Andre_Fili
# fighter_name: Andre_Fili
# https://en.wikipedia.org/wiki/Jared_Gordon
# fighter_name: Jared_Gordon
# https://en.wikipedia.org/wiki/Ignacio_Bahamondes
# fighter_name: Ignacio_Bahamondes
# https://en.wikipedia.org/wiki/Alexander_Volkanovski
# fighter_name: Alexander_Volkanovski
# https://en.wikipedia.org/wiki/Cody_Stamann
# fighter_name: Cody_Stamann
# https://en.wikipedia.org/wiki/Asu_Almabayev
# fighter_name: Asu_Almabayev
# https://en.wikipedia.org/wiki/Katlyn_Cerminara
# fighter_name: Katlyn_Cerminara
# https://en.wikipedia.org/wiki/Roman_Dolidze
# fighter_name: Roman_Dolidze
# https://en.wikipedia.org/wiki/Marcos_Rog%C3%A9rio_de_Lima
# fighter_name: Marcos_Rog%C3%A9rio_de_Lima
# https://en.wikipedia.org/wiki/Alexandre_Pantoja
# fighter_name: Alexandre_Pantoja
# https://en.wikipedia.org/wiki/Michael_Chiesa
# fighter_name: Michael_Chiesa
# https://en.wikipedia.org/wiki/Brad_Riddell
# fighter_name: Brad_Riddell
# https://en.wikipedia.org/wiki/Randy_Brown_(fighter)
# fighter_name: Randy_Brown_(fighter)
# https://en.wikipedia.org/wiki/Vicente_Luque
# fighter_name: Vicente_Luque
# https://en.wikipedia.org/wiki/Raoni_Barcelos
# fighter_name: Raoni_Barcelos
# https://en.wikipedia.org/wiki/Michael_Chandler
# fighter_name: Michael_Chandler
# https://en.wikipedia.org/wiki/Kennedy_Nzechukwu
# fighter_name: Kennedy_Nzechukwu
# https://en.wikipedia.org/wiki/Pedro_Munhoz
# fighter_name: Pedro_Munhoz
# https://en.wikipedia.org/wiki/Chidi_Njokuani
# fighter_name: Chidi_Njokuani
# https://en.wikipedia.org/wiki/Nasrat_Haqparast
# fighter_name: Nasrat_Haqparast
# https://en.wikipedia.org/wiki/Victor_Henry_(fighter)
# fighter_name: Victor_Henry_(fighter)
# https://en.wikipedia.org/wiki/Kurt_Holobaugh_(fighter)
# fighter_name: Kurt_Holobaugh_(fighter)
# https://en.wikipedia.org/wiki/Montel_Jackson
# fighter_name: Montel_Jackson
# https://en.wikipedia.org/wiki/Vince_Morales
# fighter_name: Vince_Morales
# https://en.wikipedia.org/wiki/Bill_Algeo
# fighter_name: Bill_Algeo
# https://en.wikipedia.org/wiki/Robert_Whittaker_(fighter)
# fighter_name: Robert_Whittaker_(fighter)
# https://en.wikipedia.org/wiki/Veronica_Hardy
# fighter_name: Veronica_Hardy
# https://en.wikipedia.org/wiki/Vinc_Pichel
# fighter_name: Vinc_Pichel
# https://en.wikipedia.org/wiki/Gilbert_Burns
# fighter_name: Gilbert_Burns
# https://en.wikipedia.org/wiki/Tim_Elliott
# fighter_name: Tim_Elliott
# https://en.wikipedia.org/wiki/Kai_Asakura
# fighter_name: Kai_Asakura
# https://en.wikipedia.org/wiki/Modestas_Bukauskas
# fighter_name: Modestas_Bukauskas
# https://en.wikipedia.org/wiki/Julio_Arce
# fighter_name: Julio_Arce
# https://en.wikipedia.org/wiki/Josefine_Lindgren_Knutsson
# fighter_name: Josefine_Lindgren_Knutsson
# https://en.wikipedia.org/wiki/Khaos_Williams
# fighter_name: Khaos_Williams
# https://en.wikipedia.org/wiki/Kevin_Jousset
# fighter_name: Kevin_Jousset
# https://en.wikipedia.org/wiki/Armen_Petrosyan_(fighter)
# fighter_name: Armen_Petrosyan_(fighter)
# https://en.wikipedia.org/wiki/Jai_Herbert
# fighter_name: Jai_Herbert
# https://en.wikipedia.org/wiki/T.J._Brown
# fighter_name: T.J._Brown
# https://en.wikipedia.org/wiki/Amir_Albazi
# fighter_name: Amir_Albazi
# https://en.wikipedia.org/wiki/Gillian_Robertson
# fighter_name: Gillian_Robertson
# https://en.wikipedia.org/wiki/Norma_Dumont
# fighter_name: Norma_Dumont
# https://en.wikipedia.org/wiki/Melissa_Gatto
# fighter_name: Melissa_Gatto
# https://en.wikipedia.org/wiki/Grant_Dawson
# fighter_name: Grant_Dawson
# https://en.wikipedia.org/wiki/Douglas_Silva_de_Andrade
# fighter_name: Douglas_Silva_de_Andrade
# https://en.wikipedia.org/wiki/Gabriel_Ben%C3%ADtez
# fighter_name: Gabriel_Ben%C3%ADtez
# https://en.wikipedia.org/wiki/Yana_Santos
# fighter_name: Yana_Santos
# https://en.wikipedia.org/wiki/Geoff_Neal
# fighter_name: Geoff_Neal
# https://en.wikipedia.org/wiki/Jamall_Emmers
# fighter_name: Jamall_Emmers
# https://en.wikipedia.org/wiki/Rong_Zhu
# fighter_name: Rong_Zhu
# https://en.wikipedia.org/wiki/Mayra_Bueno_Silva
# fighter_name: Mayra_Bueno_Silva
# https://en.wikipedia.org/wiki/Marcin_Tybura
# fighter_name: Marcin_Tybura
# https://en.wikipedia.org/wiki/Warlley_Alves
# fighter_name: Warlley_Alves
# https://en.wikipedia.org/wiki/Loma_Lookboonmee
# fighter_name: Loma_Lookboonmee
# https://en.wikipedia.org/wiki/Alex_Morono
# fighter_name: Alex_Morono
# https://en.wikipedia.org/wiki/Serghei_Spivac
# fighter_name: Serghei_Spivac
# https://en.wikipedia.org/wiki/Stipe_Miocic
# fighter_name: Stipe_Miocic
# https://en.wikipedia.org/wiki/Miesha_Tate
# fighter_name: Miesha_Tate
# https://en.wikipedia.org/wiki/Renato_Moicano
# fighter_name: Renato_Moicano
# https://en.wikipedia.org/wiki/Priscila_Cachoeira
# fighter_name: Priscila_Cachoeira
# https://en.wikipedia.org/wiki/Eryk_Anders
# fighter_name: Eryk_Anders
# https://en.wikipedia.org/wiki/Joel_%C3%81lvarez
# fighter_name: Joel_%C3%81lvarez
# https://en.wikipedia.org/wiki/Kai_Kara-France
# fighter_name: Kai_Kara-France
# https://en.wikipedia.org/wiki/Rose_Namajunas
# fighter_name: Rose_Namajunas
# https://en.wikipedia.org/wiki/Magomed_Ankalaev
# fighter_name: Magomed_Ankalaev
# https://en.wikipedia.org/wiki/Beneil_Dariush
# fighter_name: Beneil_Dariush
# https://en.wikipedia.org/wiki/Sodiq_Yusuff
# fighter_name: Sodiq_Yusuff
# https://en.wikipedia.org/wiki/Payton_Talbott
# fighter_name: Payton_Talbott
# https://en.wikipedia.org/wiki/Bruno_Gustavo_da_Silva
# fighter_name: Bruno_Gustavo_da_Silva
# https://en.wikipedia.org/wiki/Vanessa_Demopoulos
# fighter_name: Vanessa_Demopoulos
# https://en.wikipedia.org/wiki/Tom_Aspinall
# fighter_name: Tom_Aspinall
# https://en.wikipedia.org/wiki/%C4%BDudov%C3%ADt_Klein
# fighter_name: %C4%BDudov%C3%ADt_Klein
# https://en.wikipedia.org/wiki/Muslim_Salikhov
# fighter_name: Muslim_Salikhov
# https://en.wikipedia.org/wiki/Nassourdine_Imavov
# fighter_name: Nassourdine_Imavov
# https://en.wikipedia.org/wiki/Stephen_Thompson_(fighter)
# fighter_name: Stephen_Thompson_(fighter)
# https://en.wikipedia.org/wiki/Jasmine_Jasudavicius
# fighter_name: Jasmine_Jasudavicius
# https://en.wikipedia.org/wiki/Chris_Curtis_(fighter)
# fighter_name: Chris_Curtis_(fighter)
# https://en.wikipedia.org/wiki/Cong_Wang
# fighter_name: Cong_Wang
# https://en.wikipedia.org/wiki/Germaine_de_Randamie
# fighter_name: Germaine_de_Randamie
# https://en.wikipedia.org/wiki/Sharabutdin_Magomedov
# fighter_name: Sharabutdin_Magomedov
# https://en.wikipedia.org/wiki/Tajikistan
# fighter_name: Tajikistan
# No suitable table found with at least 4 columns.
# https://en.wikipedia.org/wiki/Song_Yadong
# fighter_name: Song_Yadong
# https://en.wikipedia.org/wiki/Ciryl_Gane
# fighter_name: Ciryl_Gane
# https://en.wikipedia.org/wiki/Cody_Gibson
# fighter_name: Cody_Gibson
# https://en.wikipedia.org/wiki/Tabatha_Ricci
# fighter_name: Tabatha_Ricci
# https://en.wikipedia.org/wiki/Dustin_Stoltzfus
# fighter_name: Dustin_Stoltzfus
# https://en.wikipedia.org/wiki/Bobby_Green
# fighter_name: Bobby_Green
# https://en.wikipedia.org/wiki/Alexander_Romanov_(fighter)
# fighter_name: Alexander_Romanov_(fighter)
# https://en.wikipedia.org/wiki/Tatsuro_Taira
# fighter_name: Tatsuro_Taira
# https://en.wikipedia.org/wiki/Nikita_Krylov
# fighter_name: Nikita_Krylov
# https://en.wikipedia.org/wiki/Pannie_Kianzad
# fighter_name: Pannie_Kianzad
# https://en.wikipedia.org/wiki/Don%27Tale_Mayes
# fighter_name: Don%27Tale_Mayes
# https://en.wikipedia.org/wiki/Taylor_Lapilus
# fighter_name: Taylor_Lapilus
# https://en.wikipedia.org/wiki/Jun_Yong_Park
# fighter_name: Jun_Yong_Park
# https://en.wikipedia.org/wiki/Julian_Marquez
# fighter_name: Julian_Marquez
# https://en.wikipedia.org/wiki/Jamahal_Hill
# fighter_name: Jamahal_Hill
# https://en.wikipedia.org/wiki/Nathaniel_Wood_(fighter)
# fighter_name: Nathaniel_Wood_(fighter)
# https://en.wikipedia.org/wiki/Chris_Weidman
# fighter_name: Chris_Weidman
# https://en.wikipedia.org/wiki/Mateusz_Gamrot
# fighter_name: Mateusz_Gamrot
# https://en.wikipedia.org/wiki/Beno%C3%AEt_Saint_Denis
# fighter_name: Beno%C3%AEt_Saint_Denis
# https://en.wikipedia.org/wiki/Michael_Page
# fighter_name: Michael_Page
# https://en.wikipedia.org/wiki/Kevin_Holland
# fighter_name: Kevin_Holland
# https://en.wikipedia.org/wiki/Pat_Sabatini
# fighter_name: Pat_Sabatini
# https://en.wikipedia.org/wiki/Karine_Silva
# fighter_name: Karine_Silva
# https://en.wikipedia.org/wiki/Adrian_Yanez
# fighter_name: Adrian_Yanez
# https://en.wikipedia.org/wiki/Mike_Davis_(fighter)
# fighter_name: Mike_Davis_(fighter)
# https://en.wikipedia.org/wiki/Yan_Xiaonan
# fighter_name: Yan_Xiaonan
# https://en.wikipedia.org/wiki/Max_Holloway
# fighter_name: Max_Holloway
# https://en.wikipedia.org/wiki/Natan_Levy
# fighter_name: Natan_Levy
# https://en.wikipedia.org/wiki/Mario_Bautista
# fighter_name: Mario_Bautista
# https://en.wikipedia.org/wiki/Choi_Doo-ho
# fighter_name: Choi_Doo-ho
# https://en.wikipedia.org/wiki/Farid_Basharat
# fighter_name: Farid_Basharat
# https://en.wikipedia.org/wiki/Brianna_Fortino
# fighter_name: Brianna_Fortino
# https://en.wikipedia.org/wiki/Neil_Magny
# fighter_name: Neil_Magny
# https://en.wikipedia.org/wiki/Austen_Lane
# fighter_name: Austen_Lane
# https://en.wikipedia.org/wiki/Steve_Garcia
# fighter_name: Steve_Garcia
# https://en.wikipedia.org/wiki/Gavin_Tucker
# fighter_name: Gavin_Tucker
# https://en.wikipedia.org/wiki/Merab_Dvalishvili
# fighter_name: Merab_Dvalishvili
# https://en.wikipedia.org/wiki/Christos_Giagos
# fighter_name: Christos_Giagos
# https://en.wikipedia.org/wiki/Daniel_Marcos
# fighter_name: Daniel_Marcos
# https://en.wikipedia.org/wiki/Josiane_Nunes
# fighter_name: Josiane_Nunes
# https://en.wikipedia.org/wiki/Dustin_Poirier
# fighter_name: Dustin_Poirier
# https://en.wikipedia.org/wiki/Mizuki_Inoue
# fighter_name: Mizuki_Inoue
# https://en.wikipedia.org/wiki/Brian_Ortega
# fighter_name: Brian_Ortega
# https://en.wikipedia.org/wiki/Ariane_Carnelossi
# fighter_name: Ariane_Carnelossi
# https://en.wikipedia.org/wiki/Conor_McGregor
# fighter_name: Conor_McGregor
# https://en.wikipedia.org/wiki/Volkan_Oezdemir
# fighter_name: Volkan_Oezdemir
# https://en.wikipedia.org/wiki/Chris_Barnett
# fighter_name: Chris_Barnett
# https://en.wikipedia.org/wiki/Jeremiah_Wells
# fighter_name: Jeremiah_Wells
# https://en.wikipedia.org/wiki/Mickey_Gall
# fighter_name: Mickey_Gall
# https://en.wikipedia.org/wiki/Tecia_Pennington
# fighter_name: Tecia_Pennington
# https://en.wikipedia.org/wiki/Michael_Johnson_(fighter)
# fighter_name: Michael_Johnson_(fighter)
# https://en.wikipedia.org/wiki/Alonzo_Menifield
# fighter_name: Alonzo_Menifield
# https://en.wikipedia.org/wiki/Brandon_Royval
# fighter_name: Brandon_Royval
# https://en.wikipedia.org/wiki/Jamie_Mullarkey
# fighter_name: Jamie_Mullarkey
# https://en.wikipedia.org/wiki/Nick_Diaz
# fighter_name: Nick_Diaz
# https://en.wikipedia.org/wiki/Terrance_McKinney
# fighter_name: Terrance_McKinney
# https://en.wikipedia.org/wiki/Steve_Erceg
# fighter_name: Steve_Erceg
# https://en.wikipedia.org/wiki/Josh_Emmett
# fighter_name: Josh_Emmett
# https://en.wikipedia.org/wiki/Danyelle_Wolf
# fighter_name: Danyelle_Wolf
# https://en.wikipedia.org/wiki/Amanda_Lemos
# fighter_name: Amanda_Lemos
# https://en.wikipedia.org/wiki/Jalin_Turner
# fighter_name: Jalin_Turner
# https://en.wikipedia.org/wiki/Bryce_Mitchell
# fighter_name: Bryce_Mitchell
# https://en.wikipedia.org/wiki/Slovakia
# fighter_name: Slovakia
# No suitable table found with at least 4 columns.
# https://en.wikipedia.org/wiki/Manon_Fiorot
# fighter_name: Manon_Fiorot
# https://en.wikipedia.org/wiki/Matt_Frevola
# fighter_name: Matt_Frevola
# https://en.wikipedia.org/wiki/Tai_Tuivasa
# fighter_name: Tai_Tuivasa
# https://en.wikipedia.org/wiki/Danny_Roberts_(fighter)
# fighter_name: Danny_Roberts_(fighter)
# https://en.wikipedia.org/wiki/Herbert_Burns
# fighter_name: Herbert_Burns
# https://en.wikipedia.org/wiki/Marc-Andr%C3%A9_Barriault
# fighter_name: Marc-Andr%C3%A9_Barriault
# https://en.wikipedia.org/wiki/Dan_Ige
# fighter_name: Dan_Ige
# https://en.wikipedia.org/wiki/Joaquim_Silva_(fighter)
# fighter_name: Joaquim_Silva_(fighter)
# https://en.wikipedia.org/wiki/Colby_Covington
# fighter_name: Colby_Covington
# https://en.wikipedia.org/wiki/Ode%27_Osbourne
# fighter_name: Ode%27_Osbourne
# https://en.wikipedia.org/wiki/Tim_Means
# fighter_name: Tim_Means
# https://en.wikipedia.org/wiki/Choi_Seung-woo
# fighter_name: Choi_Seung-woo
# No suitable table found with at least 4 columns.
# https://en.wikipedia.org/wiki/Moldova
# fighter_name: Moldova
# No suitable table found with at least 4 columns.
# https://en.wikipedia.org/wiki/Sean_O%27Malley_(fighter)
# fighter_name: Sean_O%27Malley_(fighter)
# https://en.wikipedia.org/wiki/Kyle_Nelson_(fighter)
# fighter_name: Kyle_Nelson_(fighter)
# https://en.wikipedia.org/wiki/Park_Jun-yong
# fighter_name: Park_Jun-yong
# https://en.wikipedia.org/wiki/Alexander_Volkov_(fighter)
# fighter_name: Alexander_Volkov_(fighter)
# https://en.wikipedia.org/wiki/Song_Kenan
# fighter_name: Song_Kenan
# https://en.wikipedia.org/wiki/Victoria_Leonardo
# fighter_name: Victoria_Leonardo
# https://en.wikipedia.org/wiki/Robelis_Despaigne
# fighter_name: Robelis_Despaigne
# https://en.wikipedia.org/wiki/Johnny_Walker_(fighter)
# fighter_name: Johnny_Walker_(fighter)
# https://en.wikipedia.org/wiki/Bruno_Silva_(fighter)
# fighter_name: Bruno_Silva_(fighter)
# https://en.wikipedia.org/wiki/Ikram_Aliskerov
# fighter_name: Ikram_Aliskerov
# https://en.wikipedia.org/wiki/United_States_Anti-Doping_Agency
# fighter_name: United_States_Anti-Doping_Agency
# No suitable table found with at least 4 columns.
# https://en.wikipedia.org/wiki/Ricky_Glenn
# fighter_name: Ricky_Glenn
# https://en.wikipedia.org/wiki/Carlos_Diego_Ferreira
# fighter_name: Carlos_Diego_Ferreira
# https://en.wikipedia.org/wiki/Aleksandar_Raki%C4%87
# fighter_name: Aleksandar_Raki%C4%87
# https://en.wikipedia.org/wiki/Talita_Alencar
# fighter_name: Talita_Alencar
# https://en.wikipedia.org/wiki/Ketlen_Vieira
# fighter_name: Ketlen_Vieira
# https://en.wikipedia.org/wiki/Abdul_Razak_Alhassan
# fighter_name: Abdul_Razak_Alhassan
# https://en.wikipedia.org/wiki/Jhonata_Diniz
# fighter_name: Jhonata_Diniz
# https://en.wikipedia.org/wiki/Lando_Vannata
# fighter_name: Lando_Vannata
# https://en.wikipedia.org/wiki/Rayanne_dos_Santos
# fighter_name: Rayanne_dos_Santos
# https://en.wikipedia.org/wiki/Davey_Grant
# fighter_name: Davey_Grant
# https://en.wikipedia.org/wiki/Holly_Holm
# fighter_name: Holly_Holm
# https://en.wikipedia.org/wiki/Shavkat_Rakhmonov
# fighter_name: Shavkat_Rakhmonov
# https://en.wikipedia.org/wiki/Clay_Guida
# fighter_name: Clay_Guida
# https://en.wikipedia.org/wiki/Sean_Woodson
# fighter_name: Sean_Woodson
# https://en.wikipedia.org/wiki/Rafael_Fiziev
# fighter_name: Rafael_Fiziev
# https://en.wikipedia.org/wiki/Daniel_Rodriguez_(fighter)
# fighter_name: Daniel_Rodriguez_(fighter)
# https://en.wikipedia.org/wiki/Ricardo_Ramos_(fighter)
# fighter_name: Ricardo_Ramos_(fighter)
# https://en.wikipedia.org/wiki/Cameron_Saaiman
# fighter_name: Cameron_Saaiman
# https://en.wikipedia.org/wiki/Micha%C5%82_Oleksiejczuk
# fighter_name: Micha%C5%82_Oleksiejczuk
# https://en.wikipedia.org/wiki/Yazmin_Jauregui
# fighter_name: Yazmin_Jauregui
# https://en.wikipedia.org/wiki/Darren_Elkins
# fighter_name: Darren_Elkins
# https://en.wikipedia.org/wiki/Marcin_Prachnio
# fighter_name: Marcin_Prachnio
# https://en.wikipedia.org/wiki/Beno%C3%AEt_Saint-Denis
# fighter_name: Beno%C3%AEt_Saint-Denis
# https://en.wikipedia.org/wiki/Virna_Jandiroba
# fighter_name: Virna_Jandiroba
# https://en.wikipedia.org/wiki/Edson_Barboza
# fighter_name: Edson_Barboza
# https://en.wikipedia.org/wiki/Rodolfo_Vieira
# fighter_name: Rodolfo_Vieira
# https://en.wikipedia.org/wiki/Macy_Chiasson
# fighter_name: Macy_Chiasson
# https://en.wikipedia.org/wiki/Tagir_Ulanbekov
# fighter_name: Tagir_Ulanbekov
# https://en.wikipedia.org/wiki/Gerald_Meerschaert
# fighter_name: Gerald_Meerschaert
# https://en.wikipedia.org/wiki/Philip_Rowe
# fighter_name: Philip_Rowe
# https://en.wikipedia.org/wiki/Jessica_Penne
# fighter_name: Jessica_Penne
# https://en.wikipedia.org/wiki/Bo_Nickal
# fighter_name: Bo_Nickal
# https://en.wikipedia.org/wiki/Jack_Shore
# fighter_name: Jack_Shore
# https://en.wikipedia.org/wiki/Azamat_Murzakanov
# fighter_name: Azamat_Murzakanov
# https://en.wikipedia.org/wiki/Kyler_Phillips
# fighter_name: Kyler_Phillips

# %%
ufc_records_added = {}
for url in added_url_lst[:]:
    print(url)
    fighter_name = url[30:]
    print('fighter_name:', fighter_name)
    try:
        record = extract_ufc_record(url)
        if record is not None:
            ufc_records_added[fighter_name] = record
    except:
        print(f"broke on: {url}")
# Out:
# https://en.wikipedia.org/wiki/Ariane_Lipski
# fighter_name: Ariane_Lipski
# https://en.wikipedia.org/wiki/Muhammad_Mokaev
# fighter_name: Muhammad_Mokaev
# https://en.wikipedia.org/wiki/Francis_Ngannou
# fighter_name: Francis_Ngannou
# https://en.wikipedia.org/wiki/Michelle_Waterson-Gomez
# fighter_name: Michelle_Waterson-Gomez

# %%
# ufc_records_dict_lst = []
# for k, v in ufc_records.items():
#     ufc_records_dict_lst.append({k: v.to_dict()})
# with open('data/ufc_wiki_raw.json', 'w') as f:
#     json.dump(ufc_records_dict_lst, f, indent=4)

# %%
ufc_records_dict_lst_added = []
for k, v in ufc_records_added.items():
    ufc_records_dict_lst_added.append({k: v.to_dict()})

# %%
with open('data/ufc_wiki_raw.json', 'r') as file:
    ufc_records_dict_lst = json.load(file)

# %%
ufc_records_dict_lst_added = []
for k, v in ufc_records_added.items():
    ufc_records_dict_lst_added.append({k: v.to_dict()})

# %%
len(ufc_records_dict_lst)
# Out:
# 378

# %%
ufc_records_dict_lst = ufc_records_dict_lst + ufc_records_dict_lst_added

# %%
len(ufc_records_dict_lst), len(ufc_records_dict_lst_added)
# Out:
# (382, 4)

# %%
with open('data/ufc_wiki_raw_v2.json', 'w') as f:
    json.dump(ufc_records_dict_lst, f, indent=4)

# %%
ufc_records = {}
for item in ufc_records_dict_lst:
    # Each item is a dictionary with a single key-value pair
    # We use .items() to get the key and value
    for k, v in item.items():
        ufc_records[k] = pd.DataFrame(v) if isinstance(v, dict) else v

# %%
def parse_dates(date_list):
    date_series = pd.Series(date_list)
    parsed_dates = pd.to_datetime(date_series.str.replace('–', '-').str.replace('[377]', ''), errors='coerce')
    return parsed_dates

ufc_records = {k: v for k, v in ufc_records.items() if all([c in v.columns for c in ['Date raw', 'Result', 'Result']])}

for k, v in ufc_records.items():
    v['Date'] = parse_dates(v['Date raw'])

# %%
ufc_records["Li_Jingliang"].head()
# Out:
#   Result Record              Opponent  \
# 0   Loss   19–9         Carlos Prates
# 1   Loss   19–8      Daniel Rodriguez
# 2    Win   19–7       Muslim Salikhov
# 3   Loss   18–7       Khamzat Chimaev
# 4    Win   18–6  Santiago Ponzinibbio
#
#                                     Method                             Event  \
# 0                             KO (punches)                           UFC 305
# 1                         Decision (split)                           UFC 279
# 2                 TKO (punches and elbows)  UFC on ABC: Ortega vs. Rodríguez
# 3  Technical Submission (rear-naked choke)                           UFC 267
# 4                               KO (punch)   UFC on ABC: Holloway vs. Kattar
#
#              Date raw Round  Time                         Location  \
# 0     August 18, 2024     2  4:02                 Perth, Australia
# 1  September 10, 2022     3  5:00  Las Vegas,Nevada, United States
# 2       July 16, 2022     2  4:38  Elmont, New York, United States
# 3    October 30, 2021     1  3:16  Abu Dhabi, United Arab Emirates
# 4    January 16, 2021     1  4:25  Abu Dhabi, United Arab Emirates
#
#                         Notes       Date
# 0                             2024-08-18
# 1  Catchweight (180 lb) bout. 2022-09-10
# 2   Performance of the Night. 2022-07-16
# 3                             2021-10-30
# 4   Performance of the Night. 2021-01-16

# %%
ufc_matches = []
for k, v in ufc_records.items():
    fighter = urllib.parse.unquote(k.replace('_', ' ').replace('(fighter)', '').strip())
    logi = v['Date'].isnull()
    print(f"Dropping: {logi.sum()}")
    
    ufc_matches.append(v[~logi].assign(Fighter=fighter)[['Fighter', 'Opponent', 'Result', 'Date', 'Date raw']])

ufc_matches_df = pd.concat(ufc_matches, axis=0).reset_index(drop=True)
# Out:
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 2
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 2
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 2
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 2
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 4
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 44
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 16
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 29
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 2
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 2
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 2
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 17
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 2
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 2
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0

# %%
ufc_matches_df.head()
# Out:
#          Fighter                Opponent Result       Date          Date raw
# 0  Derrick Lewis      Rodrigo Nascimento    Win 2024-05-11      May 11, 2024
# 1  Derrick Lewis         Jailton Almeida   Loss 2023-11-04  November 4, 2023
# 2  Derrick Lewis  Marcos Rogério de Lima    Win 2023-07-29     July 29, 2023
# 3  Derrick Lewis          Serghei Spivac   Loss 2023-02-04  February 4, 2023
# 4  Derrick Lewis        Sergei Pavlovich   Loss 2022-07-30     July 30, 2022

# %%
ufc_matches_df.shape
# Out:
# (8795, 5)

# %%
ufc_matches_df['Result'].unique()
# Out:
# array(['Win', 'Loss', 'NC', 'Draw'], dtype=object)

# %%
ufc_matches_df = ufc_matches_df[ufc_matches_df['Result'].isin(['Win', 'Loss'])]

# %%
mapper = {'Loss':0, 
          'Win':1}
ufc_matches_df['Outcome'] = ufc_matches_df['Result'].apply(lambda x: mapper[x])

# %%
fighters = set(ufc_matches_df['Fighter'])
opponents = set(ufc_matches_df['Opponent'])
# fighters - opponents

# %%
def count_histogram_overlap(str1, str2):
    hist1 = Counter(str1)
    hist2 = Counter(str2)
    common_chars = set(hist1.keys()).intersection(set(hist2.keys()))
    overlap = 0
    for char in common_chars:
        overlap += min(hist1[char], hist2[char])
    
    return overlap / (len(str1) + len(str2))

# %%
names_all = list(fighters | opponents)
names_all = sorted(names_all)
chr_overlap = [np.nan]

for i in range(1, len(names_all)):
    chr_overlap.append(count_histogram_overlap(names_all[i-1], names_all[i]))

df = pd.DataFrame(dict(names_all=names_all, chr_overlap = chr_overlap))

# %%
top_indices = df.sort_values('chr_overlap', ascending=False).head(20).index
indices_ch = []

for ti in top_indices:
    indices_ch.append(ti - 1)
    indices_ch.append(ti)

df.loc[indices_ch]
# Out:
#                     names_all  chr_overlap
# 518    Baasankhuu Damlanpurev     0.161290
# 519   Baasankhuu Damnlanpurev     0.488889
# 25       Abdulhalik Magomedov     0.350000
# 26      Abdulkhalik Magomedov     0.487805
# 1658          Gaetano Pirello     0.277778
# 1659         Gaetano Pirrello     0.483871
# 4593            Tyler Bialeck     0.272727
# 4594           Tyler Bialecki     0.481481
# 3781            Rafael Correa     0.392857
# 3782           Rafael Correia     0.481481
# 3963              Robert Reed     0.280000
# 3964             Robert Rende     0.478261
# 1165               Dave Moran     0.350000
# 1166              Dave Morgan     0.476190
# 558        Benoît Saint Denis     0.322581
# 559        Benoît Saint-Denis     0.472222
# 3698        Paulina Borkowska     0.236842
# 3699        Paulina Bońkowska     0.470588
# 1937         Isabela de Padua     0.269231
# 1938         Isabela de Pádua     0.468750
# 1720          Gilberto Galvao     0.357143
# 1721          Gilberto Galvão     0.466667
# 3743          Piera Rodriguez     0.275862
# 3744          Piera Rodríguez     0.466667
# 632             Brandon Adams     0.333333
# 633           Brandon Adamson     0.464286
# 2101           Jason Gonzales     0.346154
# 2102           Jason Gonzalez     0.464286
# 654              Brandon Vega     0.333333
# 655              Brandon Vera     0.458333
# 76               Adrian Yanez     0.360000
# 77               Adrian Yañez     0.458333
# 2083             Jared Gooden     0.333333
# 2084             Jared Gordon     0.458333
# 1296              Diego Lopes     0.205882
# 1297              Diego Lopez     0.454545
# 3909         Richard Montalvo     0.343750
# 3910          Richard Montano     0.451613
# 3328           Michel Pereira     0.366667
# 3329          Michel Prazeres     0.448276

# %%
name_changes = {}
name_changes["Baasankhuu Damnlanpurev"] = "Baasankhuu Damlanpurev"
name_changes["Abdulhalik Magomedov"] = "Abdulkhalik Magomedov"
name_changes["Gaetano Pirello"] = "Gaetano Pirrello"
name_changes["Rafael Correa"] = "Rafael Correia"
name_changes["Tyler Bialeck"] = "Tyler Bialecki"
name_changes["Dave Moran"] = "Dave Morgan"
name_changes["Benoît Saint Denis"] = "Benoît Saint-Denis"
name_changes["Isabela de Padua"] = "Isabela de Pádua"
name_changes["Gilberto Galvao"] = "Gilberto Galvão"
name_changes["Piera Rodriguez"] = "Piera Rodríguez"
name_changes["Adrian Yanez"] = "Adrian Yañez"
name_changes["Diego Lopez"] = "Diego Lopes"

# %%
for c in ['Fighter', 'Opponent']:
    ufc_matches_df[c] = ufc_matches_df[c].apply(lambda x: name_changes[x] if x in name_changes else x)
    ufc_matches_df[c] = ufc_matches_df[c].str.replace('Jr.', 'Jr')
    ufc_matches_df[c] = ufc_matches_df[c].str.replace('Sr.', 'Sr')

# %%
ufc_matches_df['key'] = np.nan

for i, row in ufc_matches_df.iterrows():
    f, o, d = row['Fighter'], row['Opponent'], row['Date']
    if f < o:
        k = f'{f}_{o}_{d}'
    else:
        k = f'{o}_{f}_{d}'
    ufc_matches_df.loc[i, 'key'] = k
# Out:
# /var/folders/sg/52_wwpld14z_lvc4rf4zy9x00000gn/T/ipykernel_46891/3768447274.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Derrick Lewis_Rodrigo Nascimento_2024-05-11 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ufc_matches_df.loc[i, 'key'] = k

# %%
ufc_matches_df = ufc_matches_df.drop_duplicates(subset=['key']).sort_values(['Date', 'Fighter']).reset_index(drop=True)

# %%
ufc_matches_df.head()
# Out:
#            Fighter           Opponent Result       Date          Date raw  \
# 0  Andrei Arlovski  Viacheslav Datsik   Loss 1999-04-09      9 April 1999
# 1  Andrei Arlovski      Roman Zentsov    Win 2000-04-09      9 April 2000
# 2  Andrei Arlovski   Michael Tielrooy    Win 2000-04-09      9 April 2000
# 3  Andrei Arlovski        John Dixson    Win 2000-05-13       13 May 2000
# 4  Andrei Arlovski        Aaron Brink    Win 2000-11-17  17 November 2000
#
#    Outcome                                                key
# 0        0  Andrei Arlovski_Viacheslav Datsik_1999-04-09 0...
# 1        1  Andrei Arlovski_Roman Zentsov_2000-04-09 00:00:00
# 2        1  Andrei Arlovski_Michael Tielrooy_2000-04-09 00...
# 3        1    Andrei Arlovski_John Dixson_2000-05-13 00:00:00
# 4        1    Aaron Brink_Andrei Arlovski_2000-11-17 00:00:00

# %%
ufc_matches_df.shape
# Out:
# (7660, 7)

# %%
ufc_matches_df.to_parquet('data/ufc_matches_v2.parquet')

# %%
len(ufc_matches_df), len(ufc_matches_df[ufc_matches_df.Outcome==1]), len(ufc_matches_df[ufc_matches_df.Outcome==0])
# Out:
# (7660, 5975, 1685)

# %%
len(ufc_matches_df)==len(ufc_matches_df[ufc_matches_df.Outcome==1])+len(ufc_matches_df[ufc_matches_df.Outcome==0])
# Out:
# True

# %%
type(ufc_matches_df.iloc[0].Date)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
ufc_matches_df['Winner'] = ufc_matches_df.apply(lambda row: row.Fighter if row.Outcome==1 else row.Opponent, axis=1)

# %%
ufc_matches_df['Loser'] = ufc_matches_df.apply(lambda row: row.Opponent if row.Outcome==1 else row.Fighter, axis=1)

# %%
ufc_matches_df.head()
# Out:
#            Fighter           Opponent Result       Date          Date raw  \
# 0  Andrei Arlovski  Viacheslav Datsik   Loss 1999-04-09      9 April 1999
# 1  Andrei Arlovski      Roman Zentsov    Win 2000-04-09      9 April 2000
# 2  Andrei Arlovski   Michael Tielrooy    Win 2000-04-09      9 April 2000
# 3  Andrei Arlovski        John Dixson    Win 2000-05-13       13 May 2000
# 4  Andrei Arlovski        Aaron Brink    Win 2000-11-17  17 November 2000
#
#    Outcome                                                key  \
# 0        0  Andrei Arlovski_Viacheslav Datsik_1999-04-09 0...
# 1        1  Andrei Arlovski_Roman Zentsov_2000-04-09 00:00:00
# 2        1  Andrei Arlovski_Michael Tielrooy_2000-04-09 00...
# 3        1    Andrei Arlovski_John Dixson_2000-05-13 00:00:00
# 4        1    Aaron Brink_Andrei Arlovski_2000-11-17 00:00:00
#
#               Winner             Loser
# 0  Viacheslav Datsik   Andrei Arlovski
# 1    Andrei Arlovski     Roman Zentsov
# 2    Andrei Arlovski  Michael Tielrooy
# 3    Andrei Arlovski       John Dixson
# 4    Andrei Arlovski       Aaron Brink

# %%
ufc_matches_df = ufc_matches_df.rename(columns={'Winner': 'winner', 'Loser': 'loser', 'Date': 'timestamp'})

# %%
ufc_matches_df[['winner', 'loser', 'timestamp']].to_parquet("data/ufc_matches_refined_v2.parquet")

# %%
#ufc_matches_df = pd.read_parquet("data/ufc_matches_refined.parquet")

# %%
self = TrueSkillThroughTimeApplied(ufc_matches_df)

# %%
print(ufc_matches_df.head().to_string())
# Out:
#            Fighter           Opponent Result  timestamp          Date raw  Outcome                                                    key             winner             loser  time_0_to_999_int
# 0  Andrei Arlovski  Viacheslav Datsik   Loss 1999-04-09      9 April 1999        0  Andrei Arlovski_Viacheslav Datsik_1999-04-09 00:00:00  Viacheslav Datsik   Andrei Arlovski                  0
# 1  Andrei Arlovski      Roman Zentsov    Win 2000-04-09      9 April 2000        1      Andrei Arlovski_Roman Zentsov_2000-04-09 00:00:00    Andrei Arlovski     Roman Zentsov                 39
# 2  Andrei Arlovski   Michael Tielrooy    Win 2000-04-09      9 April 2000        1   Andrei Arlovski_Michael Tielrooy_2000-04-09 00:00:00    Andrei Arlovski  Michael Tielrooy                 39
# 3  Andrei Arlovski        John Dixson    Win 2000-05-13       13 May 2000        1        Andrei Arlovski_John Dixson_2000-05-13 00:00:00    Andrei Arlovski       John Dixson                 42
# 4  Andrei Arlovski        Aaron Brink    Win 2000-11-17  17 November 2000        1        Aaron Brink_Andrei Arlovski_2000-11-17 00:00:00    Andrei Arlovski       Aaron Brink                 62

# %%
self.learn_optimal_parameters()
# Out:
# gamma: 0.0200, sigma: 0.0200, beta: 0.0200,
# NLE: 4455.1450
#
# gamma: 0.0200, sigma: 0.0200, beta: 0.0200,
# NLE: 4455.1450
#
# gamma: 0.0200, sigma: 0.0200, beta: 0.0200,
# NLE: 4455.1450
#
# gamma: 0.0200, sigma: 0.0200, beta: 0.0200,
# NLE: 4455.1450
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 5221.3064
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 5221.3064
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 5221.3064
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 5221.3064
#
# gamma: 0.0366, sigma: 0.0366, beta: 0.0366,
# NLE: 4210.0036
#
# gamma: 0.0366, sigma: 0.0366, beta: 0.0366,
# NLE: 4210.0036
#
# gamma: 0.0366, sigma: 0.0366, beta: 0.0366,
# NLE: 4210.0036
#
# gamma: 0.0366, sigma: 0.0366, beta: 0.0366,
# NLE: 4210.0036
#
# gamma: 0.0697, sigma: 0.0697, beta: 0.0697,
# NLE: 4209.2526
#
# gamma: 0.0697, sigma: 0.0697, beta: 0.0697,
# NLE: 4209.2526
#
# gamma: 0.0697, sigma: 0.0697, beta: 0.0697,
# NLE: 4209.2526
#
# gamma: 0.0697, sigma: 0.0697, beta: 0.0697,
# NLE: 4209.2526
#
# gamma: 0.0679, sigma: 0.0679, beta: 0.0679,
# NLE: 4209.2691
#
# gamma: 0.0679, sigma: 0.0679, beta: 0.0679,
# NLE: 4209.2691
#
# gamma: 0.0679, sigma: 0.0679, beta: 0.0679,
# NLE: 4209.2691
#
# gamma: 0.0679, sigma: 0.0679, beta: 0.0679,
# NLE: 4209.2691
#
# gamma: 0.0693, sigma: 0.0693, beta: 0.0693,
# NLE: 4209.2532
#
# gamma: 0.0693, sigma: 0.0693, beta: 0.0693,
# NLE: 4209.2532
#
# gamma: 0.0693, sigma: 0.0693, beta: 0.0693,
# NLE: 4209.2532
#
# gamma: 0.0693, sigma: 0.0693, beta: 0.0693,
# NLE: 4209.2532
#
# gamma: 0.0696, sigma: 0.0696, beta: 0.0696,
# NLE: 4209.2526
#
# gamma: 0.0696, sigma: 0.0696, beta: 0.0696,
# NLE: 4209.2526
#
# gamma: 0.0696, sigma: 0.0696, beta: 0.0696,
# NLE: 4209.2526
#
# gamma: 0.0696, sigma: 0.0696, beta: 0.0696,
# NLE: 4209.2526
#
# gamma: 0.0697, sigma: 0.0697, beta: 0.0697,
# NLE: 4209.2526
#
# gamma: 0.0697, sigma: 0.0697, beta: 0.0697,
# NLE: 4209.2526
#
# gamma: 0.0697, sigma: 0.0697, beta: 0.0697,
# NLE: 4209.2526
#
# gamma: 0.0697, sigma: 0.0697, beta: 0.0697,
# NLE: 4209.2526
#
# gamma: 0.0562, sigma: 0.0562, beta: 0.0562,
# NLE: 4209.3479
#
# gamma: 0.0562, sigma: 0.0562, beta: 0.0562,
# NLE: 4209.3479
#
# gamma: 0.0562, sigma: 0.0562, beta: 0.0562,
# NLE: 4209.3479
#
# gamma: 0.0562, sigma: 0.0562, beta: 0.0562,
# NLE: 4209.3479
#
# gamma: 0.0661, sigma: 0.0661, beta: 0.0661,
# NLE: 4209.2425
#
# gamma: 0.0661, sigma: 0.0661, beta: 0.0661,
# NLE: 4209.2425
#
# gamma: 0.0661, sigma: 0.0661, beta: 0.0661,
# NLE: 4209.2425
#
# gamma: 0.0661, sigma: 0.0661, beta: 0.0661,
# NLE: 4209.2425
#
# gamma: 0.0678, sigma: 0.0678, beta: 0.0678,
# NLE: 4209.2441
#
# gamma: 0.0678, sigma: 0.0678, beta: 0.0678,
# NLE: 4209.2441
#
# gamma: 0.0678, sigma: 0.0678, beta: 0.0678,
# NLE: 4209.2441
#
# gamma: 0.0678, sigma: 0.0678, beta: 0.0678,
# NLE: 4209.2441
#
# gamma: 0.0666, sigma: 0.0666, beta: 0.0666,
# NLE: 4209.2424
#
# gamma: 0.0666, sigma: 0.0666, beta: 0.0666,
# NLE: 4209.2424
#
# gamma: 0.0666, sigma: 0.0666, beta: 0.0666,
# NLE: 4209.2424
#
# gamma: 0.0666, sigma: 0.0666, beta: 0.0666,
# NLE: 4209.2424
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 4210.6351
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 4210.6351
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 4210.6351
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 4210.6351
#
# gamma: 0.0692, sigma: 0.0692, beta: 0.0692,
# NLE: 4209.2490
#
# gamma: 0.0692, sigma: 0.0692, beta: 0.0692,
# NLE: 4209.2490
#
# gamma: 0.0692, sigma: 0.0692, beta: 0.0692,
# NLE: 4209.2490
#
# gamma: 0.0692, sigma: 0.0692, beta: 0.0692,
# NLE: 4209.2490
#
# gamma: 0.0672, sigma: 0.0672, beta: 0.0672,
# NLE: 4209.2426
#
# gamma: 0.0672, sigma: 0.0672, beta: 0.0672,
# NLE: 4209.2426
#
# gamma: 0.0672, sigma: 0.0672, beta: 0.0672,
# NLE: 4209.2426
#
# gamma: 0.0672, sigma: 0.0672, beta: 0.0672,
# NLE: 4209.2426
#
# gamma: 0.0667, sigma: 0.0667, beta: 0.0667,
# NLE: 4209.2424
#
# gamma: 0.0667, sigma: 0.0667, beta: 0.0667,
# NLE: 4209.2424
#
# gamma: 0.0667, sigma: 0.0667, beta: 0.0667,
# NLE: 4209.2424
#
# gamma: 0.0667, sigma: 0.0667, beta: 0.0667,
# NLE: 4209.2424
#
# gamma: 0.0666, sigma: 0.0666, beta: 0.0666,
# NLE: 4209.2421
#
# gamma: 0.0666, sigma: 0.0666, beta: 0.0666,
# NLE: 4209.2421
#
# gamma: 0.0666, sigma: 0.0666, beta: 0.0666,
# NLE: 4209.2421
#
# gamma: 0.0666, sigma: 0.0666, beta: 0.0666,
# NLE: 4209.2421
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0662, sigma: 0.0662, beta: 0.0662,
# NLE: 4209.2413
#
# gamma: 0.0662, sigma: 0.0662, beta: 0.0662,
# NLE: 4209.2413
#
# gamma: 0.0662, sigma: 0.0662, beta: 0.0662,
# NLE: 4209.2413
#
# gamma: 0.0662, sigma: 0.0662, beta: 0.0662,
# NLE: 4209.2413
#
# gamma: 0.0660, sigma: 0.0660, beta: 0.0660,
# NLE: 4209.2410
#
# gamma: 0.0660, sigma: 0.0660, beta: 0.0660,
# NLE: 4209.2410
#
# gamma: 0.0660, sigma: 0.0660, beta: 0.0660,
# NLE: 4209.2410
#
# gamma: 0.0660, sigma: 0.0660, beta: 0.0660,
# NLE: 4209.2410
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
#
# gamma: 0.0659, sigma: 0.0659, beta: 0.0659,
# NLE: 4209.2409
# optimal gamma : 0.0659
# optimal sigma : 3.9321
# optimal beta : 2.4791

# %%
#NLE: 4209.2409
optimal_gamma = 0.0659
optimal_sigma = 3.9321
optimal_beta = 2.4791

# %%
self.set_optimal_parameters(gamma = optimal_gamma, sigma = optimal_sigma, beta = optimal_beta)

# %%
skill_curves = self.set_skill_curves()

# %%
# https://en.wikipedia.org/wiki/UFC_rankings
top_fighters_online = ['Islam Makhachev', 'Alex Pereira', 'Jon Jones', 'Ilia Topuria', 'Belal Muhammad', 'Dricus du Plessis', \
                       'Merab Dvalishvili', 'Tom Aspinall', 'Leon Edwards', 'Alexander Volkanovski', 'Max Holloway', \
                        'Alexandre Pantoja', "Sean O'Malley", 'Sean Strickland', 'Charles Oliveira']

# %%
self.plot_player_skills(players = top_fighters_online, width=1500, burnin=0)
# Out:
# alt.LayerChart(...)

# %%
self.plot_calibration()
# Out:
# /Users/davidliu/Desktop/Python312/true_theta/posts/trueskill/true_skill_through_time.py:204: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   bucket_means = df.groupby('win_prob_bucket').agg(
# alt.LayerChart(...)

# %% [markdown]
# ### the calibration plot on the entire 7660 games dataset is very similar to the boxing data
