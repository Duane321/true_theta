# %%
import pandas as pd
import numpy as np
import altair as alt
import requests
from bs4 import BeautifulSoup
import json

# %%
from true_skill_through_time import *

# %%
# boxer_wiki_urls contains the wikipedia URLs of a large list of boxers
with open('data/boxer_wiki_urls.txt', 'r') as file:
    urls = file.readlines()

urls = [url.strip() for url in urls]

# %%
def extract_boxing_record(url):
    """
    Given a boxer's Wikipedia URL, this will extract the table called "Professional boxing record" and do some cleanup.
    """
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    section = None
    for header in soup.find_all(['h2', 'h3', 'h4']):
        if 'Professional boxing record' in header.get_text():
            section = header
            break
    
    if section:
        tables = section.find_all_next('table')
        
        for table in tables:
            first_row = table.find('tr')
            columns = first_row.find_all(['th', 'td'])
            
            if len(columns) >= 4:
                headers = [header.get_text(strip=True) for header in table.find_all('th')]
                rows = []
                for row in table.find_all('tr')[1:]:  # Skip header row if present
                    cells = row.find_all(['th', 'td'])
                    rows.append([cell.get_text(strip=True) for cell in cells])
                df = pd.DataFrame(rows, columns=headers if headers else None).rename(columns={'Date': "Date raw", 'Res.':'Result'})
                return df 
                
    print('No suitable table found with at least 4 columns.')
    return None

# %% [markdown]
# ### It takes about 20 mins to pull the raw data from Wikipedia

# %%
boxing_records = {}

for url in urls:
    print(url)
    boxer_name = url[30:]
    try:
        record = extract_boxing_record(url)
        if record is not None:
            boxing_records[boxer_name] = record
    except:
        print(f"broke on: {url}")
# Out:
# https://en.wikipedia.org/wiki/William_Abelyan
# No suitable table found with at least 4 columns.
# https://en.wikipedia.org/wiki/Arthur_Abraham
# https://en.wikipedia.org/wiki/Miguel_Acosta_(boxer)
# https://en.wikipedia.org/wiki/Tomasz_Adamek
# https://en.wikipedia.org/wiki/Ola_Afolabi
# No suitable table found with at least 4 columns.
# https://en.wikipedia.org/wiki/Joachim_Alcine
# https://en.wikipedia.org/wiki/Devon_Alexander
# https://en.wikipedia.org/wiki/Jos%C3%A9_Alfaro_(boxer)
# https://en.wikipedia.org/wiki/Muhammad_Ali
# https://en.wikipedia.org/wiki/Canelo_%C3%81lvarez
# https://en.wikipedia.org/wiki/Elvis_%C3%81lvarez
# No suitable table found with at least 4 columns.
# https://en.wikipedia.org/wiki/Sa%C3%BAl_%C3%81lvarez
# https://en.wikipedia.org/wiki/Lou_Ambers
# https://en.wikipedia.org/wiki/Sammy_Angott
# https://en.wikipedia.org/wiki/Alfredo_Angulo
# https://en.wikipedia.org/wiki/Vito_Antuofermo
# https://en.wikipedia.org/wiki/Fred_Apostoli
# https://en.wikipedia.org/wiki/Jorge_Arce
# https://en.wikipedia.org/wiki/Alexis_Arg%C3%BCello
# https://en.wikipedia.org/wiki/Henry_Armstrong
# https://en.wikipedia.org/wiki/Mike_Arnaoutis
# https://en.wikipedia.org/wiki/Chris_Arreola
# https://en.wikipedia.org/wiki/Lenin_Arroyo
# No suitable table found with at least 4 columns.
# https://en.wikipedia.org/wiki/Mike_Alvarado
# https://en.wikipedia.org/wiki/Alex_Arthur
# https://en.wikipedia.org/wiki/Amin_Asikainen
# https://en.wikipedia.org/wiki/Abe_Attell
# https://en.wikipedia.org/wiki/Emanuel_Augustus
# https://en.wikipedia.org/wiki/Ray_Austin_(boxer)
# https://en.wikipedia.org/wiki/Bonifacio_%C3%81vila
# No suitable table found with at least 4 columns.
# https://en.wikipedia.org/wiki/Alexander_Awdijan
# No suitable table found with at least 4 columns.
# https://en.wikipedia.org/wiki/
# No suitable table found with at least 4 columns.
# https://en.wikipedia.org/wiki/Fritzie_Zivic
# https://en.wikipedia.org/wiki/Stefano_Zoff
# https://en.wikipedia.org/wiki/Henriques_Zowa
# No suitable table found with at least 4 columns.
# https://en.wikipedia.org/wiki/Fulgencio_Z%C3%BA%C3%B1iga
# No suitable table found with at least 4 columns.

# %% [markdown]
# ### save the raw Wikipedia data

# %%
# boxing_records_dict_lst = []
# for k, v in boxing_records.items():
#     boxing_records_dict_lst.append({k: v.to_dict()})
# with open('data/boxer_wiki_raw.json', 'w') as f:
#     json.dump(boxing_records_dict_lst, f, indent=4)

# %%
boxing_records["Arthur_Abraham"].head()
# Out:
#   No. Result Record          Opponent Type  Round, time     Date raw  \
# 0  53    Win   47–6   Patrick Nielsen   SD           12  28 Apr 2018
# 1  52   Loss   46–6  Chris Eubank Jr.   UD           12  15 Jul 2017
# 2  51    Win   46–5    Robin Krasniqi   UD           12  22 Apr 2017
# 3  50    Win   45–5  Tim-Robin Lihaug  TKO  8 (12),1:09  16 Jul 2016
# 4  49   Loss   44–5  Gilberto Ramírez   UD           12   9 Apr 2016
#
#                                       Location  \
# 0              Baden-Arena, Offenburg, Germany
# 1        The SSE Arena Wembley,London, England
# 2                       Messe, Erfurt, Germany
# 3         Max-Schmeling-Halle, Berlin, Germany
# 4  MGM Grand Garden Arena,Paradise, Nevada, US
#
#                                                Notes       Date
# 0  Won vacant WBO International super-middleweigh... 2018-04-28
# 1                    ForIBO super-middleweight title 2017-07-15
# 2                                                    2017-04-22
# 3  Won vacant WBO International super-middleweigh... 2016-07-16
# 4                  Lost WBO super-middleweight title 2016-04-09

# %% [markdown]
# ## Parse the raw data from wikipedia into a propert pandas datetime series.

# %%
def parse_dates(date_list):
    date_series = pd.Series(date_list)
    parsed_dates = pd.to_datetime(date_series.str.replace('–', '-').str.replace('[377]', ''), errors='coerce')
    return parsed_dates

boxing_records = {k: v for k, v in boxing_records.items() if all([c in v.columns for c in ['Date raw', 'Result', 'Result']])}

for k, v in boxing_records.items():
    v['Date'] = parse_dates(v['Date raw'])
# Out:
# /var/folders/sg/52_wwpld14z_lvc4rf4zy9x00000gn/T/ipykernel_49179/3129308124.py:3: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   parsed_dates = pd.to_datetime(date_series.str.replace('–', '-').str.replace('[377]', ''), errors='coerce')
# /var/folders/sg/52_wwpld14z_lvc4rf4zy9x00000gn/T/ipykernel_49179/3129308124.py:3: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   parsed_dates = pd.to_datetime(date_series.str.replace('–', '-').str.replace('[377]', ''), errors='coerce')
# /var/folders/sg/52_wwpld14z_lvc4rf4zy9x00000gn/T/ipykernel_49179/3129308124.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed_dates = pd.to_datetime(date_series.str.replace('–', '-').str.replace('[377]', ''), errors='coerce')
# /var/folders/sg/52_wwpld14z_lvc4rf4zy9x00000gn/T/ipykernel_49179/3129308124.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed_dates = pd.to_datetime(date_series.str.replace('–', '-').str.replace('[377]', ''), errors='coerce')
# /var/folders/sg/52_wwpld14z_lvc4rf4zy9x00000gn/T/ipykernel_49179/3129308124.py:3: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   parsed_dates = pd.to_datetime(date_series.str.replace('–', '-').str.replace('[377]', ''), errors='coerce')
# /var/folders/sg/52_wwpld14z_lvc4rf4zy9x00000gn/T/ipykernel_49179/3129308124.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed_dates = pd.to_datetime(date_series.str.replace('–', '-').str.replace('[377]', ''), errors='coerce')
# /var/folders/sg/52_wwpld14z_lvc4rf4zy9x00000gn/T/ipykernel_49179/3129308124.py:3: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   parsed_dates = pd.to_datetime(date_series.str.replace('–', '-').str.replace('[377]', ''), errors='coerce')

# %%
boxing_records["Arthur_Abraham"].head()
# Out:
#   No. Result Record          Opponent Type  Round, time     Date raw  \
# 0  53    Win   47–6   Patrick Nielsen   SD           12  28 Apr 2018
# 1  52   Loss   46–6  Chris Eubank Jr.   UD           12  15 Jul 2017
# 2  51    Win   46–5    Robin Krasniqi   UD           12  22 Apr 2017
# 3  50    Win   45–5  Tim-Robin Lihaug  TKO  8 (12),1:09  16 Jul 2016
# 4  49   Loss   44–5  Gilberto Ramírez   UD           12   9 Apr 2016
#
#                                       Location  \
# 0              Baden-Arena, Offenburg, Germany
# 1        The SSE Arena Wembley,London, England
# 2                       Messe, Erfurt, Germany
# 3         Max-Schmeling-Halle, Berlin, Germany
# 4  MGM Grand Garden Arena,Paradise, Nevada, US
#
#                                                Notes       Date
# 0  Won vacant WBO International super-middleweigh... 2018-04-28
# 1                    ForIBO super-middleweight title 2017-07-15
# 2                                                    2017-04-22
# 3  Won vacant WBO International super-middleweigh... 2016-07-16
# 4                  Lost WBO super-middleweight title 2016-04-09

# %% [markdown]
# Parsing dates, column naming and page naming aren't perfect. So we have to make some adjustments. Ultimately, if there's a match we can't put a date to, we drop it.

# %%
import urllib.parse

boxing_matches = []
for k, v in boxing_records.items():
    fighter = urllib.parse.unquote(k.replace('_', ' ').replace('(boxer)', '').strip())

    if fighter == 'Boxing career of Manny Pacquiao':
        fighter = 'Manny Pacquiao'

    v = v.rename(columns={'Res.':'Result'})
    logi = v['Date'].isnull()
    print(f"Dropping: {logi.sum()}")
    
    boxing_matches.append(v[~logi].assign(Fighter=fighter)[['Fighter', 'Opponent', 'Result', 'Date', 'Date raw']])

boxing_matches_df = pd.concat(boxing_matches, axis=0).reset_index(drop=True)
# Out:
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 33
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 69
# Dropping: 24
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 10
# Dropping: 0
# Dropping: 0
# Dropping: 24
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 3
# Dropping: 1
# Dropping: 0
# Dropping: 62
# Dropping: 0
# Dropping: 35
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 29
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 23
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 45
# Dropping: 107
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 1
# Dropping: 4
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 29
# Dropping: 50
# Dropping: 23
# Dropping: 0
# Dropping: 0
# Dropping: 49
# Dropping: 0
# Dropping: 0
# Dropping: 34
# Dropping: 0
# Dropping: 0
# Dropping: 4
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 109
# Dropping: 0
# Dropping: 4
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 31
# Dropping: 37
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 29
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 52
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 51
# Dropping: 0
# Dropping: 0
# Dropping: 20
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 2
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 44
# Dropping: 0
# Dropping: 0
# Dropping: 2
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 84
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 17
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 57
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 37
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 103
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 65
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 71
# Dropping: 31
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 55
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 23
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 49
# Dropping: 0
# Dropping: 47
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 40
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 44
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 32
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 87
# Dropping: 0
# Dropping: 0
# Dropping: 22
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 44
# Dropping: 0
# Dropping: 0
# Dropping: 2
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 4
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 1
# Dropping: 2
# Dropping: 24
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 50
# Dropping: 7
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 4
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 82
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 47
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 20
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 4
# Dropping: 0
# Dropping: 0
# Dropping: 42
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 14
# Dropping: 64
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 19
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 2
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 0
# Dropping: 1
# Dropping: 0
# Dropping: 0
# Dropping: 0

# %%
boxing_matches_df.head()
# Out:
#           Fighter          Opponent Result       Date     Date raw
# 0  Arthur Abraham   Patrick Nielsen    Win 2018-04-28  28 Apr 2018
# 1  Arthur Abraham  Chris Eubank Jr.   Loss 2017-07-15  15 Jul 2017
# 2  Arthur Abraham    Robin Krasniqi    Win 2017-04-22  22 Apr 2017
# 3  Arthur Abraham  Tim-Robin Lihaug    Win 2016-07-16  16 Jul 2016
# 4  Arthur Abraham  Gilberto Ramírez   Loss 2016-04-09   9 Apr 2016

# %%
boxing_matches_df.shape
# Out:
# (27710, 5)

# %%
#boxing_matches_df.to_csv("data/boxing_matches_parsed.csv", index=False)

# %%
boxing_matches = boxing_matches_df

# %% [markdown]
# ## Clean the data so that all the Wins are converts to 1's and 0's are converted to losses.
#
# The tricky thing is, Wikipedia has many ways to say "Win" or "Loss."

# %%
boxing_matches['Result'].unique()
# Out:
# array(['Win', 'Loss', 'Draw', 'NC', 'Won', 'ND', 'N/C|', 'Lose', 'Wim'],
#       dtype=object)

# %%
boxing_matches = boxing_matches[boxing_matches['Result'].isin(['Loss', 'Lost', 'L by TKO', 'L by KO', 'Lose', 'LOST', 'Wim', 'Win', 'Won', 'W by KO', 'W by TKO', 'W by SD', 'W by PTS'])]

# %%
mapper = {'Loss':0, 'Lost':0, 'L by TKO':0, 'L by KO':0, 'Lose':0, 'LOST':0,
          'Win':1, 'Wim':1, 'Won':1, 'W by KO':1, 'W by TKO':1, 'W by SD':1, 'W by PTS':1}
boxing_matches['Outcome'] = boxing_matches['Result'].apply(lambda x: mapper[x])
# Out:
# /var/folders/sg/52_wwpld14z_lvc4rf4zy9x00000gn/T/ipykernel_49179/542322897.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing_matches['Outcome'] = boxing_matches['Result'].apply(lambda x: mapper[x])

# %% [markdown]
# ## Cleaning up Fighter Names
#
# Sometimes, a fighter's name will appear differently on their own page than on another fighters page. So we have to map them to be the same string. We do this by guessing which names are likely misspellings of each (by counting overlaps in their character histogram). Then we map the names with a manually created dictionary.

# %%
fighters = set(boxing_matches['Fighter'])
opponents = set(boxing_matches['Opponent'])
# fighters - opponents

# %%
from collections import Counter

def count_histogram_overlap(str1, str2):
    hist1 = Counter(str1)
    hist2 = Counter(str2)
    common_chars = set(hist1.keys()).intersection(set(hist2.keys()))
    overlap = 0
    for char in common_chars:
        overlap += min(hist1[char], hist2[char])
    
    return overlap / (len(str1) + len(str2))

# %%
names_all = list(fighters | opponents)
names_all = sorted(names_all)
chr_overlap = [np.nan]

for i in range(1, len(names_all)):
    chr_overlap.append(count_histogram_overlap(names_all[i-1], names_all[i]))

df = pd.DataFrame(dict(names_all=names_all, chr_overlap = chr_overlap))

# %%
top_indices = df.sort_values('chr_overlap', ascending=False).head(20).index
indices_ch = []

for ti in top_indices:
    indices_ch.append(ti - 1)
    indices_ch.append(ti)

df.loc[indices_ch]
# Out:
#                   names_all  chr_overlap
# 10885   Miguel Angel Saurez     0.414634
# 10886   Miguel Angel Suarez     0.500000
# 11426       Nikolay Emereev     0.310345
# 11427       Nikolay Eremeev     0.500000
# 5392          George Monroe     0.370370
# 5393          George Moreno     0.500000
# 1573          Bill Haderman     0.260870
# 1574          Bill Hardeman     0.500000
# 12719           Rey Megrino     0.291667
# 12720           Rey Migreno     0.500000
# 13391   Rubén Darío Palacio     0.416667
# 13392  Rubén Darío Palacios     0.487179
# 5363     George Kambosos Jr     0.314286
# 5364    George Kambosos Jr.     0.486486
# 15255     Vicente Worrel Jr     0.387097
# 15256    Vicente Worrel Jr.     0.485714
# 14042     Singnum Chuwatana     0.263158
# 14043    Singnum Chuwattana     0.485714
# 449      Alejandro Sanabria     0.393939
# 450       Alejandro Sarabia     0.485714
# 15477     Wandee Singwancha     0.233333
# 15478    Wandee Singwangcha     0.485714
# 5494     German Gastelbondo     0.352941
# 5495      German Gatelbondo     0.485714
# 14334    Svein Erik Paulsen     0.171429
# 14335     Sven Erik Paulsen     0.485714
# 11155      Mohammed Medjadi     0.285714
# 11156     Mohammed Medjadji     0.484848
# 15849      Young Corbett II     0.241379
# 15850     Young Corbett III     0.484848
# 7458       Jimmy Lyggett Sr     0.448276
# 7459      Jimmy Lyggett Sr.     0.484848
# 3720       Donnie Pendelton     0.344828
# 3721        Donnie Penelton     0.483871
# 2648        Chris Eubank Jr     0.444444
# 2649       Chris Eubank Jr.     0.483871
# 13712      Satoshi Shingaki     0.344828
# 13713       Satoshi Shinkai     0.483871
# 6761       Jaime Castellano     0.387097
# 6762        Jaime Castellon     0.483871

# %%
name_changes = {}
name_changes["Rey Migreno"] = "Rey Megrino"
name_changes["George Ashe"] = "George Ashie"
name_changes["Stanyslav Tomkachov"] = "Stanyslav Tovkachov"
name_changes["Greg Scott-Briggs"] = "Greg Scott Briggs"
name_changes["Kongthawat Sorkitti"] = "Kongthawat Sor Kitti"
name_changes["Rogelio Castañeda"] = "Rogelio Castaneda"
name_changes["Miguel Angel Suarez"] = "Miguel Angel Saurez"
name_changes["Nikolay Eremeev"] = "Nikolay Emereev"
name_changes["Bill Haderman"] = "Bill Hardeman"
name_changes["Rubén Darío Palacios"] = "Rubén Darío Palacio"
name_changes["George Kambosos Jr."] = "George Kambosos Jr"
name_changes["Sven Erik Paulsen"] = "Svein Erik Paulsen"
name_changes["Singnum Chuwatana"] = "Singnum Chuwattana"
name_changes["Mohammed Medjadi	"] = "Mohammed Medjadji"

# %% [markdown]
# # Remove Double Counting
#
# We are trying to figure out all the boxing matches based on the boxing records from people's wikipedia page. However, that will double count! A fight will get represented twice, once for each fighter's wikipedia. So we remove them here.

# %%
for c in ['Fighter', 'Opponent']:
    boxing_matches[c] = boxing_matches[c].apply(lambda x: name_changes[x] if x in name_changes else x)
    boxing_matches[c] = boxing_matches[c].str.replace('Jr.', 'Jr')
    boxing_matches[c] = boxing_matches[c].str.replace('Sr.', 'Sr')
# Out:
# /var/folders/sg/52_wwpld14z_lvc4rf4zy9x00000gn/T/ipykernel_49179/2061171560.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing_matches[c] = boxing_matches[c].apply(lambda x: name_changes[x] if x in name_changes else x)
# /var/folders/sg/52_wwpld14z_lvc4rf4zy9x00000gn/T/ipykernel_49179/2061171560.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing_matches[c] = boxing_matches[c].str.replace('Jr.', 'Jr')
# /var/folders/sg/52_wwpld14z_lvc4rf4zy9x00000gn/T/ipykernel_49179/2061171560.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing_matches[c] = boxing_matches[c].str.replace('Sr.', 'Sr')

# %%
boxing_matches['key'] = np.nan

for i, row in boxing_matches.iterrows():
    f, o, d = row['Fighter'], row['Opponent'], row['Date']
    if f < o:
        k = f'{f}_{o}_{d}'
    else:
        k = f'{o}_{f}_{d}'
    boxing_matches.loc[i, 'key'] = k
# Out:
# /var/folders/sg/52_wwpld14z_lvc4rf4zy9x00000gn/T/ipykernel_49179/3226692351.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing_matches['key'] = np.nan
# /var/folders/sg/52_wwpld14z_lvc4rf4zy9x00000gn/T/ipykernel_49179/3226692351.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Arthur Abraham_Patrick Nielsen_2018-04-28 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   boxing_matches.loc[i, 'key'] = k

# %%
boxing_matches = boxing_matches.drop_duplicates(subset=['key']).sort_values(['Date', 'Fighter']).reset_index(drop=True)

# %%
boxing_matches.head()
# Out:
#             Fighter            Opponent Result       Date      Date raw  \
# 0      Jake Kilrain          Jack Daley    Win 1879-01-01   Jan 1, 1879
# 1      Jake Kilrain        Jem Driscoll    Win 1879-02-01   Feb 1, 1879
# 2      Jake Kilrain           Dan Dwyer    Win 1879-03-10  Mar 10, 1879
# 3  John L. Sullivan         Jack Curley    Win 1879-03-13  Mar 13, 1879
# 4  John L. Sullivan  Johnny Cocky Woods    Win 1879-03-14  Mar 14, 1879
#
#    Outcome                                                key
# 0        1        Jack Daley_Jake Kilrain_1879-01-01 00:00:00
# 1        1      Jake Kilrain_Jem Driscoll_1879-02-01 00:00:00
# 2        1         Dan Dwyer_Jake Kilrain_1879-03-10 00:00:00
# 3        1   Jack Curley_John L. Sullivan_1879-03-13 00:00:00
# 4        1  John L. Sullivan_Johnny Cocky Woods_1879-03-14...

# %% [markdown]
# ## Save the data, since the above is slow.

# %%
boxing_matches.to_parquet('data/boxing_matches.parquet')

# %% [markdown]
# ### Change the data format to Winner, Loser, Date

# %%
len(boxing_matches), len(boxing_matches[boxing_matches.Outcome==1]), len(boxing_matches[boxing_matches.Outcome==0])
# Out:
# (25651, 22161, 3490)

# %%
len(boxing_matches)==len(boxing_matches[boxing_matches.Outcome==1])+len(boxing_matches[boxing_matches.Outcome==0])
# Out:
# True

# %%
type(boxing_matches.iloc[0].Date)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
boxing_matches['Winner'] = boxing_matches.apply(lambda row: row.Fighter if row.Outcome==1 else row.Opponent, axis=1)

# %%
boxing_matches['Loser'] = boxing_matches.apply(lambda row: row.Opponent if row.Outcome==1 else row.Fighter, axis=1)

# %%
boxing_matches.tail(20)
# Out:
#                 Fighter            Opponent Result       Date      Date raw  \
# 25631   Devon Alexander          Vlad Panin   Loss 2024-05-24  May 24, 2024
# 25632    Deontay Wilder        Zhilei Zhang   Loss 2024-06-01   Jun 1, 2024
# 25633     Filip Hrgović       Daniel Dubois   Loss 2024-06-01    1 Jun 2024
# 25634    Gervonta Davis        Frank Martin    Win 2024-06-15  Jun 15, 2024
# 25635        Marco Huck  Evgenios Lazaridis    Win 2024-06-29   29 Jun 2024
# 25638  Shakur Stevenson   Artem Harutyunyan
# 25639    Román González       Rober Barrera
# 25640         Tony Yoka      Amine Boucetta
# 25641  Terence Crawford     Israil Madrimov
# 25642     Tomasz Adamek    Kasjusz Życiński
# 25643         Tony Yoka        Lamah Griggs
# 25644    Canelo Álvarez      Edgar Berlanga
# 25645    Erislandy Lara        Danny Garcia
# 25646      Saúl Álvarez      Edgar Berlanga
# 25647     Daniel Dubois      Anthony Joshua
# 25648       Jean Pascal         Terry Osias
# 25649       Hughie Fury      Christian Thun
# 25650   Muhammad Waseem     Jaba Memishishi

# %%
boxing_matches[['Winner', 'Loser', 'Date']].to_parquet("data/boxing_matches_refined.parquet")

# %% [markdown]
# ### Run true_skill_through_time

# %%
games = pd.read_parquet("data/boxing_matches_refined.parquet")

# %%
games = games.rename(columns={'Winner': 'winner', 'Loser': 'loser', 'Date': 'timestamp'})

# %%
games.to_parquet("data/boxing_matches_refined_tstt.parquet")

# %%
games = pd.read_parquet("data/boxing_matches_refined_tstt.parquet")

# %% [markdown]
# ### another run after we increase the lower bounds of params; then improve neg_log_evidence

# %%
games = pd.read_parquet("data/boxing_matches_refined_tstt.parquet")

# %%
self = TrueSkillThroughTimeApplied(games)

# %%
print(games.head().to_string())
# Out:
#              winner               loser  timestamp  time_0_to_999_int
# 0      Jake Kilrain          Jack Daley 1879-01-01                  0
# 1      Jake Kilrain        Jem Driscoll 1879-02-01                  0
# 2      Jake Kilrain           Dan Dwyer 1879-03-10                  1
# 3  John L. Sullivan         Jack Curley 1879-03-13                  1
# 4  John L. Sullivan  Johnny Cocky Woods 1879-03-14                  1

# %%
self.learn_optimal_parameters()
# Out:
# gamma: 0.0200, sigma: 0.0200, beta: 0.0200,
# NLE: 10906.1092
#
# gamma: 0.0200, sigma: 0.0200, beta: 0.0200,
# NLE: 10906.1092
#
# gamma: 0.0200, sigma: 0.0200, beta: 0.0200,
# NLE: 10906.1092
#
# gamma: 0.0200, sigma: 0.0200, beta: 0.0200,
# NLE: 10906.1092
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 17218.8764
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 17218.8765
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 17218.8764
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 17218.8764
#
# gamma: 0.0323, sigma: 0.0323, beta: 0.0323,
# NLE: 10055.8885
#
# gamma: 0.0323, sigma: 0.0323, beta: 0.0323,
# NLE: 10055.8885
#
# gamma: 0.0323, sigma: 0.0323, beta: 0.0323,
# NLE: 10055.8885
#
# gamma: 0.0323, sigma: 0.0323, beta: 0.0323,
# NLE: 10055.8885
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9948.2152
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9948.2152
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9948.2152
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9948.2152
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9944.5435
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9944.5435
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9944.5435
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9944.5435
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9942.4473
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9942.4473
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9942.4473
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9942.4473
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9939.8439
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9939.8439
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9939.8439
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9939.8439
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9928.2156
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9928.2157
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9928.2156
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9928.2156
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9909.4710
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9909.4710
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9909.4710
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9909.4710
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 11284.2303
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 11284.2303
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 11284.2303
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 11284.2303
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9830.3701
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9830.3702
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9830.3701
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9830.3701
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9744.7330
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9744.7330
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9744.7330
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9744.7330
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 11284.2303
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 11284.2303
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 11284.2303
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 11284.2303
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9748.9731
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9748.9731
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9748.9731
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9748.9731
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9744.1951
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9744.1951
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9744.1951
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9744.1951
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 11284.2303
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 11284.2303
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 11284.2303
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 11284.2303
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9750.8260
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9750.8260
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9750.8260
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9750.8260
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9744.1928
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9744.1928
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9744.1928
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9744.1928
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 10133.4633
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 10133.4634
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 10133.4634
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 10133.4633
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9680.5666
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9680.5665
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9680.5665
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9680.5666
#
# gamma: 0.0301, sigma: 0.0301, beta: 0.0301,
# NLE: 9971.7600
#
# gamma: 0.0301, sigma: 0.0301, beta: 0.0301,
# NLE: 9971.7601
#
# gamma: 0.0301, sigma: 0.0301, beta: 0.0301,
# NLE: 9971.7600
#
# gamma: 0.0301, sigma: 0.0301, beta: 0.0301,
# NLE: 9971.7600
#
# gamma: 0.0808, sigma: 0.0808, beta: 0.0808,
# NLE: 9676.0653
#
# gamma: 0.0808, sigma: 0.0808, beta: 0.0808,
# NLE: 9676.0653
#
# gamma: 0.0808, sigma: 0.0808, beta: 0.0808,
# NLE: 9676.0653
#
# gamma: 0.0808, sigma: 0.0808, beta: 0.0808,
# NLE: 9676.0653
#
# gamma: 0.0150, sigma: 0.0150, beta: 0.0150,
# NLE: 10068.2366
#
# gamma: 0.0150, sigma: 0.0150, beta: 0.0150,
# NLE: 10068.2363
#
# gamma: 0.0150, sigma: 0.0150, beta: 0.0150,
# NLE: 10068.2367
#
# gamma: 0.0150, sigma: 0.0150, beta: 0.0150,
# NLE: 10068.2365
#
# gamma: 0.0616, sigma: 0.0616, beta: 0.0616,
# NLE: 9669.2291
#
# gamma: 0.0616, sigma: 0.0616, beta: 0.0616,
# NLE: 9669.2291
#
# gamma: 0.0616, sigma: 0.0616, beta: 0.0616,
# NLE: 9669.2291
#
# gamma: 0.0616, sigma: 0.0616, beta: 0.0616,
# NLE: 9669.2291
#
# gamma: 0.0010, sigma: 0.0010, beta: 0.0010,
# NLE: 10181.9688
#
# gamma: 0.0010, sigma: 0.0010, beta: 0.0010,
# NLE: 10181.9659
#
# gamma: 0.0010, sigma: 0.0010, beta: 0.0010,
# NLE: 10181.9691
#
# gamma: 0.0010, sigma: 0.0010, beta: 0.0010,
# NLE: 10181.9680
#
# gamma: 0.0417, sigma: 0.0417, beta: 0.0417,
# NLE: 9667.0080
#
# gamma: 0.0417, sigma: 0.0417, beta: 0.0417,
# NLE: 9667.0081
#
# gamma: 0.0417, sigma: 0.0417, beta: 0.0417,
# NLE: 9667.0080
#
# gamma: 0.0417, sigma: 0.0417, beta: 0.0417,
# NLE: 9667.0080
#
# gamma: 0.0214, sigma: 0.0214, beta: 0.0214,
# NLE: 9664.4420
#
# gamma: 0.0214, sigma: 0.0214, beta: 0.0214,
# NLE: 9664.4420
#
# gamma: 0.0214, sigma: 0.0214, beta: 0.0214,
# NLE: 9664.4420
#
# gamma: 0.0214, sigma: 0.0214, beta: 0.0214,
# NLE: 9664.4420
#
# gamma: 0.0010, sigma: 0.0010, beta: 0.0010,
# NLE: 10017.8283
#
# gamma: 0.0010, sigma: 0.0010, beta: 0.0010,
# NLE: 10017.8264
#
# gamma: 0.0010, sigma: 0.0010, beta: 0.0010,
# NLE: 10017.8274
#
# gamma: 0.0010, sigma: 0.0010, beta: 0.0010,
# NLE: 10017.8294
#
# gamma: 0.0148, sigma: 0.0148, beta: 0.0148,
# NLE: 9664.2632
#
# gamma: 0.0148, sigma: 0.0148, beta: 0.0148,
# NLE: 9664.2632
#
# gamma: 0.0148, sigma: 0.0148, beta: 0.0148,
# NLE: 9664.2632
#
# gamma: 0.0148, sigma: 0.0148, beta: 0.0148,
# NLE: 9664.2632
#
# gamma: 0.0010, sigma: 0.0010, beta: 0.0010,
# NLE: 10051.9204
#
# gamma: 0.0010, sigma: 0.0010, beta: 0.0010,
# NLE: 10051.9194
#
# gamma: 0.0010, sigma: 0.0010, beta: 0.0010,
# NLE: 10051.9205
#
# gamma: 0.0010, sigma: 0.0010, beta: 0.0010,
# NLE: 10051.9202
#
# gamma: 0.0133, sigma: 0.0133, beta: 0.0133,
# NLE: 9664.7964
#
# gamma: 0.0133, sigma: 0.0133, beta: 0.0133,
# NLE: 9664.7964
#
# gamma: 0.0133, sigma: 0.0133, beta: 0.0133,
# NLE: 9664.7964
#
# gamma: 0.0133, sigma: 0.0133, beta: 0.0133,
# NLE: 9664.7964
#
# gamma: 0.0145, sigma: 0.0145, beta: 0.0145,
# NLE: 9664.2301
#
# gamma: 0.0145, sigma: 0.0145, beta: 0.0145,
# NLE: 9664.2301
#
# gamma: 0.0145, sigma: 0.0145, beta: 0.0145,
# NLE: 9664.2301
#
# gamma: 0.0145, sigma: 0.0145, beta: 0.0145,
# NLE: 9664.2301
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9664.4386
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9664.4386
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9664.4386
#
# gamma: 0.1000, sigma: 0.1000, beta: 0.1000,
# NLE: 9664.4386
#
# gamma: 0.0374, sigma: 0.0374, beta: 0.0374,
# NLE: 9664.2906
#
# gamma: 0.0374, sigma: 0.0374, beta: 0.0374,
# NLE: 9664.2906
#
# gamma: 0.0374, sigma: 0.0374, beta: 0.0374,
# NLE: 9664.2906
#
# gamma: 0.0374, sigma: 0.0374, beta: 0.0374,
# NLE: 9664.2906
#
# gamma: 0.0211, sigma: 0.0211, beta: 0.0211,
# NLE: 9664.2063
#
# gamma: 0.0211, sigma: 0.0211, beta: 0.0211,
# NLE: 9664.2063
#
# gamma: 0.0211, sigma: 0.0211, beta: 0.0211,
# NLE: 9664.2063
#
# gamma: 0.0211, sigma: 0.0211, beta: 0.0211,
# NLE: 9664.2063
#
# gamma: 0.0204, sigma: 0.0204, beta: 0.0204,
# NLE: 9664.2009
#
# gamma: 0.0204, sigma: 0.0204, beta: 0.0204,
# NLE: 9664.2009
#
# gamma: 0.0204, sigma: 0.0204, beta: 0.0204,
# NLE: 9664.2009
#
# gamma: 0.0204, sigma: 0.0204, beta: 0.0204,
# NLE: 9664.2009
#
# gamma: 0.0191, sigma: 0.0191, beta: 0.0191,
# NLE: 9664.1993
#
# gamma: 0.0191, sigma: 0.0191, beta: 0.0191,
# NLE: 9664.1993
#
# gamma: 0.0191, sigma: 0.0191, beta: 0.0191,
# NLE: 9664.1993
#
# gamma: 0.0191, sigma: 0.0191, beta: 0.0191,
# NLE: 9664.1993
#
# gamma: 0.0195, sigma: 0.0195, beta: 0.0195,
# NLE: 9664.1991
#
# gamma: 0.0195, sigma: 0.0195, beta: 0.0195,
# NLE: 9664.1991
#
# gamma: 0.0195, sigma: 0.0195, beta: 0.0195,
# NLE: 9664.1991
#
# gamma: 0.0195, sigma: 0.0195, beta: 0.0195,
# NLE: 9664.1991
#
# gamma: 0.0195, sigma: 0.0195, beta: 0.0195,
# NLE: 9664.1991
#
# gamma: 0.0195, sigma: 0.0195, beta: 0.0195,
# NLE: 9664.1991
#
# gamma: 0.0195, sigma: 0.0195, beta: 0.0195,
# NLE: 9664.1991
#
# gamma: 0.0195, sigma: 0.0195, beta: 0.0195,
# NLE: 9664.1991
# optimal gamma : 0.0195
# optimal sigma : 0.1454
# optimal beta : 0.0758

# %%
optimal_gamma = 0.0195
optimal_sigma = 0.1454
optimal_beta = 0.0758

# %%
self.set_optimal_parameters(gamma = optimal_gamma, sigma = optimal_sigma, beta = optimal_beta)

# %%
skill_curves = self.set_skill_curves()

# %%
# https://sports.betmgm.com/en/blog/ranking-the-worlds-top-10-boxers/
# supringly Mike Tyson is not on this list
top_boxers_online = ['Muhammad Ali', 'Joe Louis', 'Sugar Ray Robinson', 'Rocky Marciano', 'Floyd Mayweather Jr', 'Manny Pacquiao', 'Jack Dempsey', 'Roberto Durán', 'Henry Armstrong', 'Willie Pep']

# %%
self.plot_player_skills(players = top_boxers_online[:]+['Mike Tyson'], width=1500, burnin=0)
# Out:
# alt.LayerChart(...)

# %%
self.plot_player_skills(players = top_boxers_online[:]+['Mike Tyson'], width=1500, burnin=10)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Considering every available match, the GOAT of boxing is Floyd Mayweather Jr, the second best boxer would be Manny Pacquiao(his number of matches is less than 20 though)
# ### Many other great boxers have an increasing skill trend at early career then gradually decay over time, however, Floyd Mayweather Jr has a steadily increasing skill trend throughout the career.

# %%
self.plot_calibration()
# Out:
# /Users/davidliu/Desktop/Python312/true_theta/posts/trueskill/true_skill_through_time.py:206: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   x=alt.X('win_prob_midpoint', title='Predicted Win Probability'),
# alt.LayerChart(...)

# %% [markdown]
# # To-Do's
#
# - [ ] The `boxing_matches` dataset isn't quite in the right format. It needs to be the format seen in the `true_skill_wc3_dev.ipynb` notebook. The difference is, that has a `Winner` and `Loser` column. This data hasn't been organized that way, so some work needs to be done there.
# - [ ] Once it's in the right format, apply the `TrueSkillThroughTimeApplied` class, in a similar way seen in the `true_skill_wc3_dev` notebook.
# - [ ] You'll need to optimize the hyperparameters. You can use the `.learn_optimal_parameters` method for that.
# - [ ] Inspect the results. Answer the question.. who is the Greatest Of All Time? FYI, it's OK to trim the results. We don't need to consider all matches since 1911.
# - [ ] Read this paper for best practices on how to do this: https://www.herbrich.me/papers/ttt.pdf
# - [ ] To make sure we're doing things right, check out this: https://glandfried.github.io/TrueSkillThroughTime.jl/man/examples/. We could run `TrueSkillThroughTimeApplied` on the data given their (there CSV file you can download.) We should be fine, since my code uses the repo developed on that site.
# - [ ] Do some sort of out of sample test evaluation. Everything done so far has been in sample. We should hold out some future data and see if this model is good.
